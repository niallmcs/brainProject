# %%
# %matplotlib inline

from nilearn import image
from nilearn import plotting

volume = image.index_img("../data/ds105_raw/ds105/sub001/BOLD/task001_run001/bold.nii.gz", 0)

plotting.plot_glass_brain(volume, title='plot_glass_brain',
    black_bg=True, display_mode='xz')

import matplotlib.pyplot as plt
plt.show()
# Out:
# E:\Anaconda3\lib\site-packages\sklearn\utils\fixes.py:64: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if 'order' in inspect.getargspec(np.copy)[0]:

# %%
1 + 1
# Out:
# 2

# %%
import numpy as np

#gemerate some numbers
t = np.linspace(1, 10, 2000)  # 2000 points between 1 and 10
t

#plot the graph
plt.plot(t, np.cos(t))
