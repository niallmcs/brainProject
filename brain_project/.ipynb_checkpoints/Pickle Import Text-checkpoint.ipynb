# %%
import pickle
import os

path = os.path.join('..', 'data', 'story', 'smoothedTrajectoriesDifferentWindowSizes')

os.listdir(path)
# Out:
# ['smoothTrajRawIntensityMean_win10.pkl',
#  'smoothTrajRawIntensityMean_win100.pkl',
#  'smoothTrajRawIntensityMean_win20.pkl',
#  'smoothTrajRawIntensityMean_win200.pkl',
#  'smoothTrajRawIntensityMean_win50.pkl',
#  'smoothTrajRawIntensityMean_win500.pkl',
#  'smoothTrajRawValenceMean_win10.pkl',
#  'smoothTrajRawValenceMean_win100.pkl',
#  'smoothTrajRawValenceMean_win20.pkl',
#  'smoothTrajRawValenceMean_win200.pkl',
#  'smoothTrajRawValenceMean_win50.pkl',
#  'smoothTrajRawValenceMean_win500.pkl']

# %%
trajectory = pickle.load(open('smoothTrajRawValenceMean_win200.pkl', "r"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-5f06d8c6a860> in <module>()
# ----> 1 trajectory = pickle.load(open('smoothTrajRawValenceMean_win200.pkl', "r"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'smoothTrajRawValenceMean_win200.pkl'

# %%
file = open("..\\data\\story\\smoothedTrajectoriesDifferentWindowSizes\\smoothTrajRawValenceMean_win50.pkl", "rb")

# %%
trajectory = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-0cb860390b3f> in <module>()
# ----> 1 trajectory = pickle.load(file)
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xb3 in position 10: ordinal not in range(128)

# %%
import pickle
import gzip
import numpy


#http://stackoverflow.com/questions/11305790/pickle-incompatability-of-numpy-arrays-between-python-2-and-3
with open('..\\data\\story\\smoothedTrajectoriesDifferentWindowSizes\\smoothTrajRawValenceMean_win200.pkl', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    p = u.load()
    print(p)

print(p.shape)

R = 3

# %%
from scipy.signal import resample

resampled_value = resample(p, 10)
resampled_value

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.plot(p)
plt.ylabel('Subject Response')
plt.show()

# %%
import scipy.io

s3 = scipy.io.loadmat('..\\data\\plosone\\subject_3.mat', squeeze_me=True)
s3['words']
# Out:
# array([('Harry', 20, 0.5), ('had', 20.5, 0.5), ('never', 21, 0.5), ...,
#        ('thirteen', 2692, 0.5), ('was.', 2692.5, 0.5), ('+', 2693, 9)],
#       dtype=[('text', 'O'), ('start', 'O'), ('length', 'O')])

# %%
#get the first element
s3['words'][0]
# Out:
# ('Harry', 20, 0.5)

# %%
#get the time from the tuple
s3['words'][0][1]
# Out:
# 20

# %%
sample_per_second = 0.5
first_time = s3['words'][0][1]

skipped_samples = int(first_time * sample_per_second)

skipped_samples
# Out:
# 10

# %%
#get the length
len(s3['words'])
# Out:
# 5176

# %%
s3['words'][len(s3['words'])-1]
# Out:
# ('+', 2693, 9)

# %%
last_word_time_start = s3['words'][len(s3['words'])-1][1]
last_word_duration = s3['words'][len(s3['words'])-1][2]
story_ending = int(last_word_time_start + last_word_duration)
story_ending
# Out:
# 2702

# %%
#store the number of samples from the dataset
number_of_samples = 1351
number_of_samples
# Out:
# 1351

# %%
total_samples_time = int(number_of_samples / sample_per_second)
total_samples_time
# Out:
# 2702

# %%
#work out new number of valid samples
new_total_sample_time = total_samples_time - skipped_samples
new_total_sample_time
# Out:
# 2692

# %%
#get the number of samples
total_interesting_samples = int(new_total_sample_time * sample_per_second)
total_interesting_samples
# Out:
# 1346

# %%
#resample array
resampled_value = resample(p, total_interesting_samples)
resampled_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-83b441b81b2b> in <module>()
#       1 #resample array
# ----> 2 resampled_value = resample(p, total_interesting_samples)
#       3 resampled_value
#
# NameError: name 'resample' is not defined

# %%
len(resampled_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2efe68060ee2> in <module>()
# ----> 1 len(resampled_value)
#
# NameError: name 'resampled_value' is not defined

# %%
s3['words'][-10:]
# Out:
# array([('little', 2688.5, 0.5), ('package', 2689, 0.5),
#        ('from', 2689.5, 0.5), ('vault', 2690, 0.5), ('seven', 2690.5, 0.5),
#        ('hundred', 2691, 0.5), ('and', 2691.5, 0.5),
#        ('thirteen', 2692, 0.5), ('was.', 2692.5, 0.5), ('+', 2693, 9)],
#       dtype=[('text', 'O'), ('start', 'O'), ('length', 'O')])

# %%
num = 0
for value in s3['words']:
    if value[2] > num:
        num = value[2]
    if value[2] > 0.5:
        print(value)
num
# Out:
# ('+', 671, 9)
# ('+', 1375, 9)
# ('+', 1933, 9)
# ('+', 2693, 9)
# 9

# %%
for value in s3['words']:
#     if value[0] == '+':
        print(value)
# Out:
# ('Harry', 20, 0.5)
# ('had', 20.5, 0.5)
# ('never', 21, 0.5)
# ('believed', 21.5, 0.5)
# ('he', 22, 0.5)
# ('would', 22.5, 0.5)
# ('meet', 23, 0.5)
# ('a', 23.5, 0.5)
# ('boy', 24, 0.5)
# ('he', 24.5, 0.5)
# ('hated', 25, 0.5)
# ('more', 25.5, 0.5)
# ('than', 26, 0.5)
# ('Dudley,', 26.5, 0.5)
# ('but', 27, 0.5)
# ('that', 27.5, 0.5)
# ('was', 28, 0.5)
# ('before', 28.5, 0.5)
# ('he', 29, 0.5)
# ('met', 29.5, 0.5)
# ('Draco', 30, 0.5)
# ('Malfoy.', 30.5, 0.5)
# ('Still,', 31, 0.5)
# ('first-year', 31.5, 0.5)
# ('Gryffindors', 32, 0.5)
# ('only', 32.5, 0.5)
# ('had', 33, 0.5)
# ('Potions', 33.5, 0.5)
# ('with', 34, 0.5)
# ('the', 34.5, 0.5)
# ('Slytherins,', 35, 0.5)
# ('so', 35.5, 0.5)
# ('they', 36, 0.5)
# ("didn't", 36.5, 0.5)
# ('have', 37, 0.5)
# ('to', 37.5, 0.5)
# ('put', 38, 0.5)
# ('up', 38.5, 0.5)
# ('with', 39, 0.5)
# ('Malfoy', 39.5, 0.5)
# ('much.', 40, 0.5)
# ('Or', 40.5, 0.5)
# ('at', 41, 0.5)
# ('least,', 41.5, 0.5)
# ('they', 42, 0.5)
# ("didn't", 42.5, 0.5)
# ('until', 43, 0.5)
# ('they', 43.5, 0.5)
# ('spotted', 44, 0.5)
# ('a', 44.5, 0.5)
# ('notice', 45, 0.5)
# ('pinned', 45.5, 0.5)
# ('up', 46, 0.5)
# ('in', 46.5, 0.5)
# ('the', 47, 0.5)
# ('Gryffindor', 47.5, 0.5)
# ('common', 48, 0.5)
# ('room', 48.5, 0.5)
# ('that', 49, 0.5)
# ('made', 49.5, 0.5)
# ('them', 50, 0.5)
# ('all', 50.5, 0.5)
# ('groan.', 51, 0.5)
# ('Flying', 51.5, 0.5)
# ('lessons', 52, 0.5)
# ('would', 52.5, 0.5)
# ('be', 53, 0.5)
# ('starting', 53.5, 0.5)
# ('on', 54, 0.5)
# ('Thursday', 54.5, 0.5)
# ('--', 55, 0.5)
# ('and', 55.5, 0.5)
# ('Gryffindor', 56, 0.5)
# ('and', 56.5, 0.5)
# ('Slytherin', 57, 0.5)
# ('would', 57.5, 0.5)
# ('be', 58, 0.5)
# ('learning', 58.5, 0.5)
# ('together.', 59, 0.5)
# ('+', 59.5, 0.5)
# ('"Typical,"', 60, 0.5)
# ('said', 60.5, 0.5)
# ('Harry', 61, 0.5)
# ('darkly.', 61.5, 0.5)
# ('"Just', 62, 0.5)
# ('what', 62.5, 0.5)
# ('I', 63, 0.5)
# ('always', 63.5, 0.5)
# ('wanted.', 64, 0.5)
# ('To', 64.5, 0.5)
# ('make', 65, 0.5)
# ('a', 65.5, 0.5)
# ('fool', 66, 0.5)
# ('of', 66.5, 0.5)
# ('myself', 67, 0.5)
# ('on', 67.5, 0.5)
# ('a', 68, 0.5)
# ('broomstick', 68.5, 0.5)
# ('in', 69, 0.5)
# ('front', 69.5, 0.5)
# ('of', 70, 0.5)
# ('Malfoy."', 70.5, 0.5)
# ('+', 71, 0.5)
# ('He', 71.5, 0.5)
# ('had', 72, 0.5)
# ('been', 72.5, 0.5)
# ('looking', 73, 0.5)
# ('forward', 73.5, 0.5)
# ('to', 74, 0.5)
# ('learning', 74.5, 0.5)
# ('to', 75, 0.5)
# ('fly', 75.5, 0.5)
# ('more', 76, 0.5)
# ('than', 76.5, 0.5)
# ('anything', 77, 0.5)
# ('else.', 77.5, 0.5)
# ('"You', 78, 0.5)
# ("don't", 78.5, 0.5)
# ('know', 79, 0.5)
# ('that', 79.5, 0.5)
# ("you'll", 80, 0.5)
# ('make', 80.5, 0.5)
# ('a', 81, 0.5)
# ('fool', 81.5, 0.5)
# ('of', 82, 0.5)
# ('yourself,"', 82.5, 0.5)
# ('said', 83, 0.5)
# ('Ron', 83.5, 0.5)
# ('reasonably.', 84, 0.5)
# ('"Anyway,', 84.5, 0.5)
# ('I', 85, 0.5)
# ('know', 85.5, 0.5)
# ("Malfoy's", 86, 0.5)
# ('always', 86.5, 0.5)
# ('going', 87, 0.5)
# ('on', 87.5, 0.5)
# ('about', 88, 0.5)
# ('how', 88.5, 0.5)
# ('good', 89, 0.5)
# ('he', 89.5, 0.5)
# ('is', 90, 0.5)
# ('at', 90.5, 0.5)
# ('Quidditch,', 91, 0.5)
# ('but', 91.5, 0.5)
# ('I', 92, 0.5)
# ('bet', 92.5, 0.5)
# ("that's", 93, 0.5)
# ('all', 93.5, 0.5)
# ('talk."', 94, 0.5)
# ('+', 94.5, 0.5)
# ('Malfoy', 95, 0.5)
# ('certainly', 95.5, 0.5)
# ('did', 96, 0.5)
# ('talk', 96.5, 0.5)
# ('about', 97, 0.5)
# ('flying', 97.5, 0.5)
# ('a', 98, 0.5)
# ('lot.', 98.5, 0.5)
# ('He', 99, 0.5)
# ('complained', 99.5, 0.5)
# ('loudly', 100, 0.5)
# ('about', 100.5, 0.5)
# ('first', 101, 0.5)
# ('years', 101.5, 0.5)
# ('never', 102, 0.5)
# ('getting', 102.5, 0.5)
# ('on', 103, 0.5)
# ('the', 103.5, 0.5)
# ('House', 104, 0.5)
# ('Quidditch', 104.5, 0.5)
# ('teams', 105, 0.5)
# ('and', 105.5, 0.5)
# ('told', 106, 0.5)
# ('long,', 106.5, 0.5)
# ('boastful', 107, 0.5)
# ('stories', 107.5, 0.5)
# ('that', 108, 0.5)
# ('always', 108.5, 0.5)
# ('seemed', 109, 0.5)
# ('to', 109.5, 0.5)
# ('end', 110, 0.5)
# ('with', 110.5, 0.5)
# ('him', 111, 0.5)
# ('narrowly', 111.5, 0.5)
# ('escaping', 112, 0.5)
# ('Muggles', 112.5, 0.5)
# ('in', 113, 0.5)
# ('helicopters.', 113.5, 0.5)
# ('He', 114, 0.5)
# ("wasn't", 114.5, 0.5)
# ('the', 115, 0.5)
# ('only', 115.5, 0.5)
# ('one,', 116, 0.5)
# ('though:', 116.5, 0.5)
# ('the', 117, 0.5)
# ('way', 117.5, 0.5)
# ('Seamus', 118, 0.5)
# ('Finnigan', 118.5, 0.5)
# ('told', 119, 0.5)
# ('it,', 119.5, 0.5)
# ("he'd", 120, 0.5)
# ('spent', 120.5, 0.5)
# ('most', 121, 0.5)
# ('of', 121.5, 0.5)
# ('his', 122, 0.5)
# ('childhood', 122.5, 0.5)
# ('zooming', 123, 0.5)
# ('around', 123.5, 0.5)
# ('the', 124, 0.5)
# ('countryside', 124.5, 0.5)
# ('on', 125, 0.5)
# ('his', 125.5, 0.5)
# ('broomstick.', 126, 0.5)
# ('Even', 126.5, 0.5)
# ('Ron', 127, 0.5)
# ('would', 127.5, 0.5)
# ('tell', 128, 0.5)
# ('anyone', 128.5, 0.5)
# ("who'd", 129, 0.5)
# ('listen', 129.5, 0.5)
# ('about', 130, 0.5)
# ('the', 130.5, 0.5)
# ('time', 131, 0.5)
# ("he'd", 131.5, 0.5)
# ('almost', 132, 0.5)
# ('hit', 132.5, 0.5)
# ('a', 133, 0.5)
# ('hang', 133.5, 0.5)
# ('glider', 134, 0.5)
# ('on', 134.5, 0.5)
# ("Charlie's", 135, 0.5)
# ('old', 135.5, 0.5)
# ('broom.', 136, 0.5)
# ('Everyone', 136.5, 0.5)
# ('from', 137, 0.5)
# ('wizarding', 137.5, 0.5)
# ('families', 138, 0.5)
# ('talked', 138.5, 0.5)
# ('about', 139, 0.5)
# ('Quidditch', 139.5, 0.5)
# ('constantly.', 140, 0.5)
# ('Ron', 140.5, 0.5)
# ('had', 141, 0.5)
# ('already', 141.5, 0.5)
# ('had', 142, 0.5)
# ('a', 142.5, 0.5)
# ('big', 143, 0.5)
# ('argument', 143.5, 0.5)
# ('with', 144, 0.5)
# ('Dean', 144.5, 0.5)
# ('Thomas,', 145, 0.5)
# ('who', 145.5, 0.5)
# ('shared', 146, 0.5)
# ('their', 146.5, 0.5)
# ('dormitory,', 147, 0.5)
# ('about', 147.5, 0.5)
# ('soccer.', 148, 0.5)
# ('Ron', 148.5, 0.5)
# ("couldn't", 149, 0.5)
# ('see', 149.5, 0.5)
# ('what', 150, 0.5)
# ('was', 150.5, 0.5)
# ('exciting', 151, 0.5)
# ('about', 151.5, 0.5)
# ('a', 152, 0.5)
# ('game', 152.5, 0.5)
# ('with', 153, 0.5)
# ('only', 153.5, 0.5)
# ('one', 154, 0.5)
# ('ball', 154.5, 0.5)
# ('where', 155, 0.5)
# ('no', 155.5, 0.5)
# ('one', 156, 0.5)
# ('was', 156.5, 0.5)
# ('allowed', 157, 0.5)
# ('to', 157.5, 0.5)
# ('fly.', 158, 0.5)
# ('Harry', 158.5, 0.5)
# ('had', 159, 0.5)
# ('caught', 159.5, 0.5)
# ('Ron', 160, 0.5)
# ('prodding', 160.5, 0.5)
# ("Dean's", 161, 0.5)
# ('poster', 161.5, 0.5)
# ('of', 162, 0.5)
# ('West', 162.5, 0.5)
# ('Ham', 163, 0.5)
# ('soccer', 163.5, 0.5)
# ('team,', 164, 0.5)
# ('trying', 164.5, 0.5)
# ('to', 165, 0.5)
# ('make', 165.5, 0.5)
# ('the', 166, 0.5)
# ('players', 166.5, 0.5)
# ('move.', 167, 0.5)
# ('+', 167.5, 0.5)
# ('Neville', 168, 0.5)
# ('had', 168.5, 0.5)
# ('never', 169, 0.5)
# ('been', 169.5, 0.5)
# ('on', 170, 0.5)
# ('a', 170.5, 0.5)
# ('broomstick', 171, 0.5)
# ('in', 171.5, 0.5)
# ('his', 172, 0.5)
# ('life,', 172.5, 0.5)
# ('because', 173, 0.5)
# ('his', 173.5, 0.5)
# ('grandmother', 174, 0.5)
# ('had', 174.5, 0.5)
# ('never', 175, 0.5)
# ('let', 175.5, 0.5)
# ('him', 176, 0.5)
# ('near', 176.5, 0.5)
# ('one.', 177, 0.5)
# ('Privately,', 177.5, 0.5)
# ('Harry', 178, 0.5)
# ('felt', 178.5, 0.5)
# ("she'd", 179, 0.5)
# ('had', 179.5, 0.5)
# ('good', 180, 0.5)
# ('reason,', 180.5, 0.5)
# ('because', 181, 0.5)
# ('Neville', 181.5, 0.5)
# ('managed', 182, 0.5)
# ('to', 182.5, 0.5)
# ('have', 183, 0.5)
# ('an', 183.5, 0.5)
# ('extraordinary', 184, 0.5)
# ('number', 184.5, 0.5)
# ('of', 185, 0.5)
# ('accidents', 185.5, 0.5)
# ('even', 186, 0.5)
# ('with', 186.5, 0.5)
# ('both', 187, 0.5)
# ('feet', 187.5, 0.5)
# ('on', 188, 0.5)
# ('the', 188.5, 0.5)
# ('ground.', 189, 0.5)
# ('+', 189.5, 0.5)
# ('Hermione', 190, 0.5)
# ('Granger', 190.5, 0.5)
# ('was', 191, 0.5)
# ('almost', 191.5, 0.5)
# ('as', 192, 0.5)
# ('nervous', 192.5, 0.5)
# ('about', 193, 0.5)
# ('flying', 193.5, 0.5)
# ('as', 194, 0.5)
# ('Neville', 194.5, 0.5)
# ('was.', 195, 0.5)
# ('This', 195.5, 0.5)
# ('was', 196, 0.5)
# ('something', 196.5, 0.5)
# ('you', 197, 0.5)
# ("couldn't", 197.5, 0.5)
# ('learn', 198, 0.5)
# ('by', 198.5, 0.5)
# ('heart', 199, 0.5)
# ('out', 199.5, 0.5)
# ('of', 200, 0.5)
# ('a', 200.5, 0.5)
# ('book', 201, 0.5)
# ('--', 201.5, 0.5)
# ('not', 202, 0.5)
# ('that', 202.5, 0.5)
# ('she', 203, 0.5)
# ("hadn't", 203.5, 0.5)
# ('tried.', 204, 0.5)
# ('At', 204.5, 0.5)
# ('breakfast', 205, 0.5)
# ('on', 205.5, 0.5)
# ('Thursday', 206, 0.5)
# ('she', 206.5, 0.5)
# ('bored', 207, 0.5)
# ('them', 207.5, 0.5)
# ('all', 208, 0.5)
# ('stupid', 208.5, 0.5)
# ('with', 209, 0.5)
# ('flying', 209.5, 0.5)
# ('tips', 210, 0.5)
# ("she'd", 210.5, 0.5)
# ('gotten', 211, 0.5)
# ('out', 211.5, 0.5)
# ('of', 212, 0.5)
# ('a', 212.5, 0.5)
# ('library', 213, 0.5)
# ('book', 213.5, 0.5)
# ('called', 214, 0.5)
# ('@Quidditch', 214.5, 0.5)
# ('@Through', 215, 0.5)
# ('@the', 215.5, 0.5)
# ('@Ages.', 216, 0.5)
# ('Neville', 216.5, 0.5)
# ('was', 217, 0.5)
# ('hanging', 217.5, 0.5)
# ('on', 218, 0.5)
# ('to', 218.5, 0.5)
# ('her', 219, 0.5)
# ('every', 219.5, 0.5)
# ('word,', 220, 0.5)
# ('desperate', 220.5, 0.5)
# ('for', 221, 0.5)
# ('anything', 221.5, 0.5)
# ('that', 222, 0.5)
# ('might', 222.5, 0.5)
# ('help', 223, 0.5)
# ('him', 223.5, 0.5)
# ('hang', 224, 0.5)
# ('on', 224.5, 0.5)
# ('to', 225, 0.5)
# ('his', 225.5, 0.5)
# ('broomstick', 226, 0.5)
# ('later,', 226.5, 0.5)
# ('but', 227, 0.5)
# ('everybody', 227.5, 0.5)
# ('else', 228, 0.5)
# ('was', 228.5, 0.5)
# ('very', 229, 0.5)
# ('pleased', 229.5, 0.5)
# ('when', 230, 0.5)
# ("Hermione's", 230.5, 0.5)
# ('lecture', 231, 0.5)
# ('was', 231.5, 0.5)
# ('interrupted', 232, 0.5)
# ('by', 232.5, 0.5)
# ('the', 233, 0.5)
# ('arrival', 233.5, 0.5)
# ('of', 234, 0.5)
# ('the', 234.5, 0.5)
# ('mail.', 235, 0.5)
# ('+', 235.5, 0.5)
# ('Harry', 236, 0.5)
# ("hadn't", 236.5, 0.5)
# ('had', 237, 0.5)
# ('a', 237.5, 0.5)
# ('single', 238, 0.5)
# ('letter', 238.5, 0.5)
# ('since', 239, 0.5)
# ("Hagrid's", 239.5, 0.5)
# ('note,', 240, 0.5)
# ('something', 240.5, 0.5)
# ('that', 241, 0.5)
# ('Malfoy', 241.5, 0.5)
# ('had', 242, 0.5)
# ('been', 242.5, 0.5)
# ('quick', 243, 0.5)
# ('to', 243.5, 0.5)
# ('notice,', 244, 0.5)
# ('of', 244.5, 0.5)
# ('course.', 245, 0.5)
# ("Malfoy's", 245.5, 0.5)
# ('eagle', 246, 0.5)
# ('owl', 246.5, 0.5)
# ('was', 247, 0.5)
# ('always', 247.5, 0.5)
# ('bringing', 248, 0.5)
# ('him', 248.5, 0.5)
# ('packages', 249, 0.5)
# ('of', 249.5, 0.5)
# ('sweets', 250, 0.5)
# ('from', 250.5, 0.5)
# ('home,', 251, 0.5)
# ('which', 251.5, 0.5)
# ('he', 252, 0.5)
# ('opened', 252.5, 0.5)
# ('gloatingly', 253, 0.5)
# ('at', 253.5, 0.5)
# ('the', 254, 0.5)
# ('Slytherin', 254.5, 0.5)
# ('table.', 255, 0.5)
# ('+', 255.5, 0.5)
# ('A', 256, 0.5)
# ('barn', 256.5, 0.5)
# ('owl', 257, 0.5)
# ('brought', 257.5, 0.5)
# ('Neville', 258, 0.5)
# ('a', 258.5, 0.5)
# ('small', 259, 0.5)
# ('package', 259.5, 0.5)
# ('from', 260, 0.5)
# ('his', 260.5, 0.5)
# ('grandmother.', 261, 0.5)
# ('He', 261.5, 0.5)
# ('opened', 262, 0.5)
# ('it', 262.5, 0.5)
# ('excitedly', 263, 0.5)
# ('and', 263.5, 0.5)
# ('showed', 264, 0.5)
# ('them', 264.5, 0.5)
# ('a', 265, 0.5)
# ('glass', 265.5, 0.5)
# ('ball', 266, 0.5)
# ('the', 266.5, 0.5)
# ('size', 267, 0.5)
# ('of', 267.5, 0.5)
# ('a', 268, 0.5)
# ('large', 268.5, 0.5)
# ('marble,', 269, 0.5)
# ('which', 269.5, 0.5)
# ('seemed', 270, 0.5)
# ('to', 270.5, 0.5)
# ('be', 271, 0.5)
# ('full', 271.5, 0.5)
# ('of', 272, 0.5)
# ('white', 272.5, 0.5)
# ('smoke.', 273, 0.5)
# ('+', 273.5, 0.5)
# ('"It\'s', 274, 0.5)
# ('a', 274.5, 0.5)
# ('Remembrall!"', 275, 0.5)
# ('he', 275.5, 0.5)
# ('explained.', 276, 0.5)
# ('"Gran', 276.5, 0.5)
# ('knows', 277, 0.5)
# ('I', 277.5, 0.5)
# ('forget', 278, 0.5)
# ('things', 278.5, 0.5)
# ('--', 279, 0.5)
# ('this', 279.5, 0.5)
# ('tells', 280, 0.5)
# ('you', 280.5, 0.5)
# ('if', 281, 0.5)
# ("there's", 281.5, 0.5)
# ('something', 282, 0.5)
# ("you've", 282.5, 0.5)
# ('forgotten', 283, 0.5)
# ('to', 283.5, 0.5)
# ('do.', 284, 0.5)
# ('Look,', 284.5, 0.5)
# ('you', 285, 0.5)
# ('hold', 285.5, 0.5)
# ('it', 286, 0.5)
# ('tight', 286.5, 0.5)
# ('like', 287, 0.5)
# ('this', 287.5, 0.5)
# ('and', 288, 0.5)
# ('if', 288.5, 0.5)
# ('it', 289, 0.5)
# ('turns', 289.5, 0.5)
# ('red', 290, 0.5)
# ('--', 290.5, 0.5)
# ('oh', 291, 0.5)
# ('..."', 291.5, 0.5)
# ('His', 292, 0.5)
# ('face', 292.5, 0.5)
# ('fell,', 293, 0.5)
# ('because', 293.5, 0.5)
# ('the', 294, 0.5)
# ('Remembrall', 294.5, 0.5)
# ('had', 295, 0.5)
# ('suddenly', 295.5, 0.5)
# ('glowed', 296, 0.5)
# ('scarlet,', 296.5, 0.5)
# ('"...', 297, 0.5)
# ("you've", 297.5, 0.5)
# ('forgotten', 298, 0.5)
# ('something', 298.5, 0.5)
# ('..."', 299, 0.5)
# ('+', 299.5, 0.5)
# ('Neville', 300, 0.5)
# ('was', 300.5, 0.5)
# ('trying', 301, 0.5)
# ('to', 301.5, 0.5)
# ('remember', 302, 0.5)
# ('what', 302.5, 0.5)
# ("he'd", 303, 0.5)
# ('forgotten', 303.5, 0.5)
# ('when', 304, 0.5)
# ('Draco', 304.5, 0.5)
# ('Malfoy,', 305, 0.5)
# ('who', 305.5, 0.5)
# ('was', 306, 0.5)
# ('passing', 306.5, 0.5)
# ('the', 307, 0.5)
# ('Gryffindor', 307.5, 0.5)
# ('table,', 308, 0.5)
# ('snatched', 308.5, 0.5)
# ('the', 309, 0.5)
# ('Remembrall', 309.5, 0.5)
# ('out', 310, 0.5)
# ('of', 310.5, 0.5)
# ('his', 311, 0.5)
# ('hand.', 311.5, 0.5)
# ('+', 312, 0.5)
# ('Harry', 312.5, 0.5)
# ('and', 313, 0.5)
# ('Ron', 313.5, 0.5)
# ('jumped', 314, 0.5)
# ('to', 314.5, 0.5)
# ('their', 315, 0.5)
# ('feet.', 315.5, 0.5)
# ('They', 316, 0.5)
# ('were', 316.5, 0.5)
# ('half', 317, 0.5)
# ('hoping', 317.5, 0.5)
# ('for', 318, 0.5)
# ('a', 318.5, 0.5)
# ('reason', 319, 0.5)
# ('to', 319.5, 0.5)
# ('fight', 320, 0.5)
# ('Malfoy,', 320.5, 0.5)
# ('but', 321, 0.5)
# ('Professor', 321.5, 0.5)
# ('McGonagall,', 322, 0.5)
# ('who', 322.5, 0.5)
# ('could', 323, 0.5)
# ('spot', 323.5, 0.5)
# ('trouble', 324, 0.5)
# ('quicker', 324.5, 0.5)
# ('than', 325, 0.5)
# ('any', 325.5, 0.5)
# ('teacher', 326, 0.5)
# ('in', 326.5, 0.5)
# ('the', 327, 0.5)
# ('school,', 327.5, 0.5)
# ('was', 328, 0.5)
# ('there', 328.5, 0.5)
# ('in', 329, 0.5)
# ('a', 329.5, 0.5)
# ('flash.', 330, 0.5)
# ('+', 330.5, 0.5)
# ('"What\'s', 331, 0.5)
# ('going', 331.5, 0.5)
# ('on?"', 332, 0.5)
# ('+', 332.5, 0.5)
# ('"Malfoy\'s', 333, 0.5)
# ('got', 333.5, 0.5)
# ('my', 334, 0.5)
# ('Remembrall,', 334.5, 0.5)
# ('Professor."', 335, 0.5)
# ('+', 335.5, 0.5)
# ('Scowling,', 336, 0.5)
# ('Malfoy', 336.5, 0.5)
# ('quickly', 337, 0.5)
# ('dropped', 337.5, 0.5)
# ('the', 338, 0.5)
# ('Remembrall', 338.5, 0.5)
# ('back', 339, 0.5)
# ('on', 339.5, 0.5)
# ('the', 340, 0.5)
# ('table.', 340.5, 0.5)
# ('+', 341, 0.5)
# ('"Just', 341.5, 0.5)
# ('looking,"', 342, 0.5)
# ('he', 342.5, 0.5)
# ('said,', 343, 0.5)
# ('and', 343.5, 0.5)
# ('he', 344, 0.5)
# ('sloped', 344.5, 0.5)
# ('away', 345, 0.5)
# ('with', 345.5, 0.5)
# ('Crabbe', 346, 0.5)
# ('and', 346.5, 0.5)
# ('Goyle', 347, 0.5)
# ('behind', 347.5, 0.5)
# ('him.', 348, 0.5)
# ('+', 348.5, 0.5)
# ('+', 349, 0.5)
# ('At', 349.5, 0.5)
# ('three-thirty', 350, 0.5)
# ('that', 350.5, 0.5)
# ('afternoon,', 351, 0.5)
# ('Harry,', 351.5, 0.5)
# ('Ron,', 352, 0.5)
# ('and', 352.5, 0.5)
# ('the', 353, 0.5)
# ('other', 353.5, 0.5)
# ('Gryffindors', 354, 0.5)
# ('hurried', 354.5, 0.5)
# ('down', 355, 0.5)
# ('the', 355.5, 0.5)
# ('front', 356, 0.5)
# ('steps', 356.5, 0.5)
# ('onto', 357, 0.5)
# ('the', 357.5, 0.5)
# ('grounds', 358, 0.5)
# ('for', 358.5, 0.5)
# ('their', 359, 0.5)
# ('first', 359.5, 0.5)
# ('flying', 360, 0.5)
# ('lesson.', 360.5, 0.5)
# ('It', 361, 0.5)
# ('was', 361.5, 0.5)
# ('a', 362, 0.5)
# ('clear,', 362.5, 0.5)
# ('breezy', 363, 0.5)
# ('day,', 363.5, 0.5)
# ('and', 364, 0.5)
# ('the', 364.5, 0.5)
# ('grass', 365, 0.5)
# ('rippled', 365.5, 0.5)
# ('under', 366, 0.5)
# ('their', 366.5, 0.5)
# ('feet', 367, 0.5)
# ('as', 367.5, 0.5)
# ('they', 368, 0.5)
# ('marched', 368.5, 0.5)
# ('down', 369, 0.5)
# ('the', 369.5, 0.5)
# ('sloping', 370, 0.5)
# ('lawns', 370.5, 0.5)
# ('toward', 371, 0.5)
# ('a', 371.5, 0.5)
# ('smooth,', 372, 0.5)
# ('flat', 372.5, 0.5)
# ('lawn', 373, 0.5)
# ('on', 373.5, 0.5)
# ('the', 374, 0.5)
# ('opposite', 374.5, 0.5)
# ('side', 375, 0.5)
# ('of', 375.5, 0.5)
# ('the', 376, 0.5)
# ('grounds', 376.5, 0.5)
# ('to', 377, 0.5)
# ('the', 377.5, 0.5)
# ('forbidden', 378, 0.5)
# ('forest,', 378.5, 0.5)
# ('whose', 379, 0.5)
# ('trees', 379.5, 0.5)
# ('were', 380, 0.5)
# ('swaying', 380.5, 0.5)
# ('darkly', 381, 0.5)
# ('in', 381.5, 0.5)
# ('the', 382, 0.5)
# ('distance.', 382.5, 0.5)
# ('+', 383, 0.5)
# ('The', 383.5, 0.5)
# ('Slytherins', 384, 0.5)
# ('were', 384.5, 0.5)
# ('already', 385, 0.5)
# ('there,', 385.5, 0.5)
# ('and', 386, 0.5)
# ('so', 386.5, 0.5)
# ('were', 387, 0.5)
# ('twenty', 387.5, 0.5)
# ('broomsticks', 388, 0.5)
# ('lying', 388.5, 0.5)
# ('in', 389, 0.5)
# ('neat', 389.5, 0.5)
# ('lines', 390, 0.5)
# ('on', 390.5, 0.5)
# ('the', 391, 0.5)
# ('ground.', 391.5, 0.5)
# ('Harry', 392, 0.5)
# ('had', 392.5, 0.5)
# ('heard', 393, 0.5)
# ('Fred', 393.5, 0.5)
# ('and', 394, 0.5)
# ('George', 394.5, 0.5)
# ('Weasley', 395, 0.5)
# ('complain', 395.5, 0.5)
# ('about', 396, 0.5)
# ('the', 396.5, 0.5)
# ('school', 397, 0.5)
# ('brooms,', 397.5, 0.5)
# ('saying', 398, 0.5)
# ('that', 398.5, 0.5)
# ('some', 399, 0.5)
# ('of', 399.5, 0.5)
# ('them', 400, 0.5)
# ('started', 400.5, 0.5)
# ('to', 401, 0.5)
# ('vibrate', 401.5, 0.5)
# ('if', 402, 0.5)
# ('you', 402.5, 0.5)
# ('flew', 403, 0.5)
# ('too', 403.5, 0.5)
# ('high,', 404, 0.5)
# ('or', 404.5, 0.5)
# ('always', 405, 0.5)
# ('flew', 405.5, 0.5)
# ('slightly', 406, 0.5)
# ('to', 406.5, 0.5)
# ('the', 407, 0.5)
# ('left.', 407.5, 0.5)
# ('+', 408, 0.5)
# ('Their', 408.5, 0.5)
# ('teacher,', 409, 0.5)
# ('Madam', 409.5, 0.5)
# ('Hooch,', 410, 0.5)
# ('arrived.', 410.5, 0.5)
# ('She', 411, 0.5)
# ('had', 411.5, 0.5)
# ('short,', 412, 0.5)
# ('gray', 412.5, 0.5)
# ('hair,', 413, 0.5)
# ('and', 413.5, 0.5)
# ('yellow', 414, 0.5)
# ('eyes', 414.5, 0.5)
# ('like', 415, 0.5)
# ('a', 415.5, 0.5)
# ('hawk.', 416, 0.5)
# ('+', 416.5, 0.5)
# ('"Well,', 417, 0.5)
# ('what', 417.5, 0.5)
# ('are', 418, 0.5)
# ('you', 418.5, 0.5)
# ('all', 419, 0.5)
# ('waiting', 419.5, 0.5)
# ('for?"', 420, 0.5)
# ('she', 420.5, 0.5)
# ('barked.', 421, 0.5)
# ('"Everyone', 421.5, 0.5)
# ('stand', 422, 0.5)
# ('by', 422.5, 0.5)
# ('a', 423, 0.5)
# ('broomstick.', 423.5, 0.5)
# ('Come', 424, 0.5)
# ('on,', 424.5, 0.5)
# ('hurry', 425, 0.5)
# ('up."', 425.5, 0.5)
# ('+', 426, 0.5)
# ('Harry', 426.5, 0.5)
# ('glanced', 427, 0.5)
# ('down', 427.5, 0.5)
# ('at', 428, 0.5)
# ('his', 428.5, 0.5)
# ('broom.', 429, 0.5)
# ('It', 429.5, 0.5)
# ('was', 430, 0.5)
# ('old', 430.5, 0.5)
# ('and', 431, 0.5)
# ('some', 431.5, 0.5)
# ('of', 432, 0.5)
# ('the', 432.5, 0.5)
# ('twigs', 433, 0.5)
# ('stuck', 433.5, 0.5)
# ('out', 434, 0.5)
# ('at', 434.5, 0.5)
# ('odd', 435, 0.5)
# ('angles.', 435.5, 0.5)
# ('+', 436, 0.5)
# ('"Stick', 436.5, 0.5)
# ('out', 437, 0.5)
# ('your', 437.5, 0.5)
# ('right', 438, 0.5)
# ('hand', 438.5, 0.5)
# ('over', 439, 0.5)
# ('your', 439.5, 0.5)
# ('broom,"', 440, 0.5)
# ('called', 440.5, 0.5)
# ('Madam', 441, 0.5)
# ('Hooch', 441.5, 0.5)
# ('at', 442, 0.5)
# ('the', 442.5, 0.5)
# ('front,', 443, 0.5)
# ('"and', 443.5, 0.5)
# ('say', 444, 0.5)
# ('\'Up!\'"', 444.5, 0.5)
# ('+', 445, 0.5)
# ('"UP!"', 445.5, 0.5)
# ('everyone', 446, 0.5)
# ('shouted.', 446.5, 0.5)
# ('+', 447, 0.5)
# ("Harry's", 447.5, 0.5)
# ('broom', 448, 0.5)
# ('jumped', 448.5, 0.5)
# ('into', 449, 0.5)
# ('his', 449.5, 0.5)
# ('hand', 450, 0.5)
# ('at', 450.5, 0.5)
# ('once,', 451, 0.5)
# ('but', 451.5, 0.5)
# ('it', 452, 0.5)
# ('was', 452.5, 0.5)
# ('one', 453, 0.5)
# ('of', 453.5, 0.5)
# ('the', 454, 0.5)
# ('few', 454.5, 0.5)
# ('that', 455, 0.5)
# ('did.', 455.5, 0.5)
# ('Hermione', 456, 0.5)
# ("Granger's", 456.5, 0.5)
# ('had', 457, 0.5)
# ('simply', 457.5, 0.5)
# ('rolled', 458, 0.5)
# ('over', 458.5, 0.5)
# ('on', 459, 0.5)
# ('the', 459.5, 0.5)
# ('ground,', 460, 0.5)
# ('and', 460.5, 0.5)
# ("Neville's", 461, 0.5)
# ("hadn't", 461.5, 0.5)
# ('moved', 462, 0.5)
# ('at', 462.5, 0.5)
# ('all.', 463, 0.5)
# ('Perhaps', 463.5, 0.5)
# ('brooms,', 464, 0.5)
# ('like', 464.5, 0.5)
# ('horses,', 465, 0.5)
# ('could', 465.5, 0.5)
# ('tell', 466, 0.5)
# ('when', 466.5, 0.5)
# ('you', 467, 0.5)
# ('were', 467.5, 0.5)
# ('afraid,', 468, 0.5)
# ('thought', 468.5, 0.5)
# ('Harry;', 469, 0.5)
# ('there', 469.5, 0.5)
# ('was', 470, 0.5)
# ('a', 470.5, 0.5)
# ('quaver', 471, 0.5)
# ('in', 471.5, 0.5)
# ("Neville's", 472, 0.5)
# ('voice', 472.5, 0.5)
# ('that', 473, 0.5)
# ('said', 473.5, 0.5)
# ('only', 474, 0.5)
# ('too', 474.5, 0.5)
# ('clearly', 475, 0.5)
# ('that', 475.5, 0.5)
# ('he', 476, 0.5)
# ('wanted', 476.5, 0.5)
# ('to', 477, 0.5)
# ('keep', 477.5, 0.5)
# ('his', 478, 0.5)
# ('feet', 478.5, 0.5)
# ('on', 479, 0.5)
# ('the', 479.5, 0.5)
# ('ground.', 480, 0.5)
# ('+', 480.5, 0.5)
# ('Madam', 481, 0.5)
# ('Hooch', 481.5, 0.5)
# ('then', 482, 0.5)
# ('showed', 482.5, 0.5)
# ('them', 483, 0.5)
# ('how', 483.5, 0.5)
# ('to', 484, 0.5)
# ('mount', 484.5, 0.5)
# ('their', 485, 0.5)
# ('brooms', 485.5, 0.5)
# ('without', 486, 0.5)
# ('sliding', 486.5, 0.5)
# ('off', 487, 0.5)
# ('the', 487.5, 0.5)
# ('end,', 488, 0.5)
# ('and', 488.5, 0.5)
# ('walked', 489, 0.5)
# ('up', 489.5, 0.5)
# ('and', 490, 0.5)
# ('down', 490.5, 0.5)
# ('the', 491, 0.5)
# ('rows', 491.5, 0.5)
# ('correcting', 492, 0.5)
# ('their', 492.5, 0.5)
# ('grips.', 493, 0.5)
# ('Harry', 493.5, 0.5)
# ('and', 494, 0.5)
# ('Ron', 494.5, 0.5)
# ('were', 495, 0.5)
# ('delighted', 495.5, 0.5)
# ('when', 496, 0.5)
# ('she', 496.5, 0.5)
# ('told', 497, 0.5)
# ('Malfoy', 497.5, 0.5)
# ("he'd", 498, 0.5)
# ('been', 498.5, 0.5)
# ('doing', 499, 0.5)
# ('it', 499.5, 0.5)
# ('wrong', 500, 0.5)
# ('for', 500.5, 0.5)
# ('years.', 501, 0.5)
# ('+', 501.5, 0.5)
# ('"Now,', 502, 0.5)
# ('when', 502.5, 0.5)
# ('I', 503, 0.5)
# ('blow', 503.5, 0.5)
# ('my', 504, 0.5)
# ('whistle,', 504.5, 0.5)
# ('you', 505, 0.5)
# ('kick', 505.5, 0.5)
# ('off', 506, 0.5)
# ('from', 506.5, 0.5)
# ('the', 507, 0.5)
# ('ground,', 507.5, 0.5)
# ('hard,"', 508, 0.5)
# ('said', 508.5, 0.5)
# ('Madam', 509, 0.5)
# ('Hooch.', 509.5, 0.5)
# ('"Keep', 510, 0.5)
# ('your', 510.5, 0.5)
# ('brooms', 511, 0.5)
# ('steady,', 511.5, 0.5)
# ('rise', 512, 0.5)
# ('a', 512.5, 0.5)
# ('few', 513, 0.5)
# ('feet,', 513.5, 0.5)
# ('and', 514, 0.5)
# ('then', 514.5, 0.5)
# ('come', 515, 0.5)
# ('straight', 515.5, 0.5)
# ('back', 516, 0.5)
# ('down', 516.5, 0.5)
# ('by', 517, 0.5)
# ('leaning', 517.5, 0.5)
# ('forward', 518, 0.5)
# ('slightly.', 518.5, 0.5)
# ('On', 519, 0.5)
# ('my', 519.5, 0.5)
# ('whistle', 520, 0.5)
# ('--', 520.5, 0.5)
# ('three', 521, 0.5)
# ('--', 521.5, 0.5)
# ('two', 522, 0.5)
# ('--"', 522.5, 0.5)
# ('+', 523, 0.5)
# ('But', 523.5, 0.5)
# ('Neville,', 524, 0.5)
# ('nervous', 524.5, 0.5)
# ('and', 525, 0.5)
# ('jumpy', 525.5, 0.5)
# ('and', 526, 0.5)
# ('frightened', 526.5, 0.5)
# ('of', 527, 0.5)
# ('being', 527.5, 0.5)
# ('left', 528, 0.5)
# ('on', 528.5, 0.5)
# ('the', 529, 0.5)
# ('ground,', 529.5, 0.5)
# ('pushed', 530, 0.5)
# ('off', 530.5, 0.5)
# ('hard', 531, 0.5)
# ('before', 531.5, 0.5)
# ('the', 532, 0.5)
# ('whistle', 532.5, 0.5)
# ('had', 533, 0.5)
# ('touched', 533.5, 0.5)
# ('Madam', 534, 0.5)
# ("Hooch's", 534.5, 0.5)
# ('lips.', 535, 0.5)
# ('+', 535.5, 0.5)
# ('"Come', 536, 0.5)
# ('back,', 536.5, 0.5)
# ('boy!"', 537, 0.5)
# ('she', 537.5, 0.5)
# ('shouted,', 538, 0.5)
# ('but', 538.5, 0.5)
# ('Neville', 539, 0.5)
# ('was', 539.5, 0.5)
# ('rising', 540, 0.5)
# ('straight', 540.5, 0.5)
# ('up', 541, 0.5)
# ('like', 541.5, 0.5)
# ('a', 542, 0.5)
# ('cork', 542.5, 0.5)
# ('shot', 543, 0.5)
# ('out', 543.5, 0.5)
# ('of', 544, 0.5)
# ('a', 544.5, 0.5)
# ('bottle', 545, 0.5)
# ('--', 545.5, 0.5)
# ('twelve', 546, 0.5)
# ('feet', 546.5, 0.5)
# ('--', 547, 0.5)
# ('twenty', 547.5, 0.5)
# ('feet.', 548, 0.5)
# ('Harry', 548.5, 0.5)
# ('saw', 549, 0.5)
# ('his', 549.5, 0.5)
# ('scared', 550, 0.5)
# ('white', 550.5, 0.5)
# ('face', 551, 0.5)
# ('look', 551.5, 0.5)
# ('down', 552, 0.5)
# ('at', 552.5, 0.5)
# ('the', 553, 0.5)
# ('ground', 553.5, 0.5)
# ('falling', 554, 0.5)
# ('away,', 554.5, 0.5)
# ('saw', 555, 0.5)
# ('him', 555.5, 0.5)
# ('gasp,', 556, 0.5)
# ('slip', 556.5, 0.5)
# ('sideways', 557, 0.5)
# ('off', 557.5, 0.5)
# ('the', 558, 0.5)
# ('broom', 558.5, 0.5)
# ('and', 559, 0.5)
# ('--', 559.5, 0.5)
# ('+', 560, 0.5)
# ('WHAM', 560.5, 0.5)
# ('--', 561, 0.5)
# ('a', 561.5, 0.5)
# ('thud', 562, 0.5)
# ('and', 562.5, 0.5)
# ('a', 563, 0.5)
# ('nasty', 563.5, 0.5)
# ('crack', 564, 0.5)
# ('and', 564.5, 0.5)
# ('Neville', 565, 0.5)
# ('lay', 565.5, 0.5)
# ('facedown', 566, 0.5)
# ('on', 566.5, 0.5)
# ('the', 567, 0.5)
# ('grass', 567.5, 0.5)
# ('in', 568, 0.5)
# ('a', 568.5, 0.5)
# ('heap.', 569, 0.5)
# ('His', 569.5, 0.5)
# ('broomstick', 570, 0.5)
# ('was', 570.5, 0.5)
# ('still', 571, 0.5)
# ('rising', 571.5, 0.5)
# ('higher', 572, 0.5)
# ('and', 572.5, 0.5)
# ('higher,', 573, 0.5)
# ('and', 573.5, 0.5)
# ('started', 574, 0.5)
# ('to', 574.5, 0.5)
# ('drift', 575, 0.5)
# ('lazily', 575.5, 0.5)
# ('toward', 576, 0.5)
# ('the', 576.5, 0.5)
# ('forbidden', 577, 0.5)
# ('forest', 577.5, 0.5)
# ('and', 578, 0.5)
# ('out', 578.5, 0.5)
# ('of', 579, 0.5)
# ('sight.', 579.5, 0.5)
# ('+', 580, 0.5)
# ('Madam', 580.5, 0.5)
# ('Hooch', 581, 0.5)
# ('was', 581.5, 0.5)
# ('bending', 582, 0.5)
# ('over', 582.5, 0.5)
# ('Neville,', 583, 0.5)
# ('her', 583.5, 0.5)
# ('face', 584, 0.5)
# ('as', 584.5, 0.5)
# ('white', 585, 0.5)
# ('as', 585.5, 0.5)
# ('his.', 586, 0.5)
# ('"Broken', 586.5, 0.5)
# ('wrist,"', 587, 0.5)
# ('Harry', 587.5, 0.5)
# ('heard', 588, 0.5)
# ('her', 588.5, 0.5)
# ('mutter.', 589, 0.5)
# ('"Come', 589.5, 0.5)
# ('on,', 590, 0.5)
# ('boy', 590.5, 0.5)
# ('--', 591, 0.5)
# ("it's", 591.5, 0.5)
# ('all', 592, 0.5)
# ('right,', 592.5, 0.5)
# ('up', 593, 0.5)
# ('you', 593.5, 0.5)
# ('get."', 594, 0.5)
# ('+', 594.5, 0.5)
# ('She', 595, 0.5)
# ('turned', 595.5, 0.5)
# ('to', 596, 0.5)
# ('the', 596.5, 0.5)
# ('rest', 597, 0.5)
# ('of', 597.5, 0.5)
# ('the', 598, 0.5)
# ('class.', 598.5, 0.5)
# ('"None', 599, 0.5)
# ('of', 599.5, 0.5)
# ('you', 600, 0.5)
# ('is', 600.5, 0.5)
# ('to', 601, 0.5)
# ('move', 601.5, 0.5)
# ('while', 602, 0.5)
# ('I', 602.5, 0.5)
# ('take', 603, 0.5)
# ('this', 603.5, 0.5)
# ('boy', 604, 0.5)
# ('to', 604.5, 0.5)
# ('the', 605, 0.5)
# ('hospital', 605.5, 0.5)
# ('wing!', 606, 0.5)
# ('You', 606.5, 0.5)
# ('leave', 607, 0.5)
# ('those', 607.5, 0.5)
# ('brooms', 608, 0.5)
# ('where', 608.5, 0.5)
# ('they', 609, 0.5)
# ('are', 609.5, 0.5)
# ('or', 610, 0.5)
# ("you'll", 610.5, 0.5)
# ('be', 611, 0.5)
# ('out', 611.5, 0.5)
# ('of', 612, 0.5)
# ('Hogwarts', 612.5, 0.5)
# ('before', 613, 0.5)
# ('you', 613.5, 0.5)
# ('can', 614, 0.5)
# ('say', 614.5, 0.5)
# ("'Quidditch.'", 615, 0.5)
# ('Come', 615.5, 0.5)
# ('on,', 616, 0.5)
# ('dear."', 616.5, 0.5)
# ('+', 617, 0.5)
# ('Neville,', 617.5, 0.5)
# ('his', 618, 0.5)
# ('face', 618.5, 0.5)
# ('tear-streaked,', 619, 0.5)
# ('clutching', 619.5, 0.5)
# ('his', 620, 0.5)
# ('wrist,', 620.5, 0.5)
# ('hobbled', 621, 0.5)
# ('off', 621.5, 0.5)
# ('with', 622, 0.5)
# ('Madam', 622.5, 0.5)
# ('Hooch,', 623, 0.5)
# ('who', 623.5, 0.5)
# ('had', 624, 0.5)
# ('her', 624.5, 0.5)
# ('arm', 625, 0.5)
# ('around', 625.5, 0.5)
# ('him.', 626, 0.5)
# ('+', 626.5, 0.5)
# ('No', 627, 0.5)
# ('sooner', 627.5, 0.5)
# ('were', 628, 0.5)
# ('they', 628.5, 0.5)
# ('out', 629, 0.5)
# ('of', 629.5, 0.5)
# ('earshot', 630, 0.5)
# ('than', 630.5, 0.5)
# ('Malfoy', 631, 0.5)
# ('burst', 631.5, 0.5)
# ('into', 632, 0.5)
# ('laughter.', 632.5, 0.5)
# ('+', 633, 0.5)
# ('"Did', 633.5, 0.5)
# ('you', 634, 0.5)
# ('see', 634.5, 0.5)
# ('his', 635, 0.5)
# ('face,', 635.5, 0.5)
# ('the', 636, 0.5)
# ('great', 636.5, 0.5)
# ('lump?"', 637, 0.5)
# ('+', 637.5, 0.5)
# ('The', 638, 0.5)
# ('other', 638.5, 0.5)
# ('Slytherins', 639, 0.5)
# ('joined', 639.5, 0.5)
# ('in.', 640, 0.5)
# ('+', 640.5, 0.5)
# ('"Shut', 641, 0.5)
# ('up,', 641.5, 0.5)
# ('Malfoy,"', 642, 0.5)
# ('snapped', 642.5, 0.5)
# ('Parvati', 643, 0.5)
# ('Patil.', 643.5, 0.5)
# ('+', 644, 0.5)
# ('"Ooh,', 644.5, 0.5)
# ('sticking', 645, 0.5)
# ('up', 645.5, 0.5)
# ('for', 646, 0.5)
# ('Longbottom?"', 646.5, 0.5)
# ('said', 647, 0.5)
# ('Pansy', 647.5, 0.5)
# ('Parkinson,', 648, 0.5)
# ('a', 648.5, 0.5)
# ('hard-faced', 649, 0.5)
# ('Slytherin', 649.5, 0.5)
# ('girl.', 650, 0.5)
# ('"Never', 650.5, 0.5)
# ('thought', 651, 0.5)
# ("@you'd", 651.5, 0.5)
# ('like', 652, 0.5)
# ('fat', 652.5, 0.5)
# ('little', 653, 0.5)
# ('crybabies,', 653.5, 0.5)
# ('Parvati."', 654, 0.5)
# ('+', 654.5, 0.5)
# ('"Look!"', 655, 0.5)
# ('said', 655.5, 0.5)
# ('Malfoy,', 656, 0.5)
# ('darting', 656.5, 0.5)
# ('forward', 657, 0.5)
# ('and', 657.5, 0.5)
# ('snatching', 658, 0.5)
# ('something', 658.5, 0.5)
# ('out', 659, 0.5)
# ('of', 659.5, 0.5)
# ('the', 660, 0.5)
# ('grass.', 660.5, 0.5)
# ('"It\'s', 661, 0.5)
# ('that', 661.5, 0.5)
# ('stupid', 662, 0.5)
# ('thing', 662.5, 0.5)
# ("Longbottom's", 663, 0.5)
# ('gran', 663.5, 0.5)
# ('sent', 664, 0.5)
# ('him."', 664.5, 0.5)
# ('+', 665, 0.5)
# ('The', 665.5, 0.5)
# ('Remembrall', 666, 0.5)
# ('glittered', 666.5, 0.5)
# ('in', 667, 0.5)
# ('the', 667.5, 0.5)
# ('sun', 668, 0.5)
# ('as', 668.5, 0.5)
# ('he', 669, 0.5)
# ('held', 669.5, 0.5)
# ('it', 670, 0.5)
# ('up.', 670.5, 0.5)
# ('+', 671, 9)
# ('"Give', 700, 0.5)
# ('that', 700.5, 0.5)
# ('here,', 701, 0.5)
# ('Malfoy,"', 701.5, 0.5)
# ('said', 702, 0.5)
# ('Harry', 702.5, 0.5)
# ('quietly.', 703, 0.5)
# ('Everyone', 703.5, 0.5)
# ('stopped', 704, 0.5)
# ('talking', 704.5, 0.5)
# ('to', 705, 0.5)
# ('watch.', 705.5, 0.5)
# ('+', 706, 0.5)
# ('Malfoy', 706.5, 0.5)
# ('smiled', 707, 0.5)
# ('nastily.', 707.5, 0.5)
# ('"I', 708, 0.5)
# ('think', 708.5, 0.5)
# ("I'll", 709, 0.5)
# ('leave', 709.5, 0.5)
# ('it', 710, 0.5)
# ('somewhere', 710.5, 0.5)
# ('for', 711, 0.5)
# ('Longbottom', 711.5, 0.5)
# ('to', 712, 0.5)
# ('find', 712.5, 0.5)
# ('--', 713, 0.5)
# ('how', 713.5, 0.5)
# ('about', 714, 0.5)
# ('--', 714.5, 0.5)
# ('up', 715, 0.5)
# ('a', 715.5, 0.5)
# ('tree?"', 716, 0.5)
# ('+', 716.5, 0.5)
# ('"Give', 717, 0.5)
# ('it', 717.5, 0.5)
# ('@here!"', 718, 0.5)
# ('Harry', 718.5, 0.5)
# ('yelled,', 719, 0.5)
# ('but', 719.5, 0.5)
# ('Malfoy', 720, 0.5)
# ('had', 720.5, 0.5)
# ('leapt', 721, 0.5)
# ('onto', 721.5, 0.5)
# ('his', 722, 0.5)
# ('broomstick', 722.5, 0.5)
# ('and', 723, 0.5)
# ('taken', 723.5, 0.5)
# ('off.', 724, 0.5)
# ('He', 724.5, 0.5)
# ("hadn't", 725, 0.5)
# ('been', 725.5, 0.5)
# ('lying,', 726, 0.5)
# ('he', 726.5, 0.5)
# ('@could', 727, 0.5)
# ('fly', 727.5, 0.5)
# ('well.', 728, 0.5)
# ('Hovering', 728.5, 0.5)
# ('level', 729, 0.5)
# ('with', 729.5, 0.5)
# ('the', 730, 0.5)
# ('topmost', 730.5, 0.5)
# ('branches', 731, 0.5)
# ('of', 731.5, 0.5)
# ('an', 732, 0.5)
# ('oak', 732.5, 0.5)
# ('he', 733, 0.5)
# ('called,', 733.5, 0.5)
# ('"Come', 734, 0.5)
# ('and', 734.5, 0.5)
# ('get', 735, 0.5)
# ('it,', 735.5, 0.5)
# ('Potter!"', 736, 0.5)
# ('+', 736.5, 0.5)
# ('Harry', 737, 0.5)
# ('grabbed', 737.5, 0.5)
# ('his', 738, 0.5)
# ('broom.', 738.5, 0.5)
# ('+', 739, 0.5)
# ('@"No!"', 739.5, 0.5)
# ('shouted', 740, 0.5)
# ('Hermione', 740.5, 0.5)
# ('Granger.', 741, 0.5)
# ('"Madam', 741.5, 0.5)
# ('Hooch', 742, 0.5)
# ('told', 742.5, 0.5)
# ('us', 743, 0.5)
# ('not', 743.5, 0.5)
# ('to', 744, 0.5)
# ('move', 744.5, 0.5)
# ('--', 745, 0.5)
# ("you'll", 745.5, 0.5)
# ('get', 746, 0.5)
# ('us', 746.5, 0.5)
# ('all', 747, 0.5)
# ('into', 747.5, 0.5)
# ('trouble."', 748, 0.5)
# ('+', 748.5, 0.5)
# ('Harry', 749, 0.5)
# ('ignored', 749.5, 0.5)
# ('her.', 750, 0.5)
# ('Blood', 750.5, 0.5)
# ('was', 751, 0.5)
# ('pounding', 751.5, 0.5)
# ('in', 752, 0.5)
# ('his', 752.5, 0.5)
# ('ears.', 753, 0.5)
# ('He', 753.5, 0.5)
# ('mounted', 754, 0.5)
# ('the', 754.5, 0.5)
# ('broom', 755, 0.5)
# ('and', 755.5, 0.5)
# ('kicked', 756, 0.5)
# ('hard', 756.5, 0.5)
# ('against', 757, 0.5)
# ('the', 757.5, 0.5)
# ('ground', 758, 0.5)
# ('and', 758.5, 0.5)
# ('up,', 759, 0.5)
# ('up', 759.5, 0.5)
# ('he', 760, 0.5)
# ('soared;', 760.5, 0.5)
# ('air', 761, 0.5)
# ('rushed', 761.5, 0.5)
# ('through', 762, 0.5)
# ('his', 762.5, 0.5)
# ('hair,', 763, 0.5)
# ('and', 763.5, 0.5)
# ('his', 764, 0.5)
# ('robes', 764.5, 0.5)
# ('whipped', 765, 0.5)
# ('out', 765.5, 0.5)
# ('behind', 766, 0.5)
# ('him', 766.5, 0.5)
# ('--', 767, 0.5)
# ('and', 767.5, 0.5)
# ('in', 768, 0.5)
# ('a', 768.5, 0.5)
# ('rush', 769, 0.5)
# ('of', 769.5, 0.5)
# ('fierce', 770, 0.5)
# ('joy', 770.5, 0.5)
# ('he', 771, 0.5)
# ('realized', 771.5, 0.5)
# ("he'd", 772, 0.5)
# ('found', 772.5, 0.5)
# ('something', 773, 0.5)
# ('he', 773.5, 0.5)
# ('could', 774, 0.5)
# ('do', 774.5, 0.5)
# ('without', 775, 0.5)
# ('being', 775.5, 0.5)
# ('taught', 776, 0.5)
# ('--', 776.5, 0.5)
# ('this', 777, 0.5)
# ('was', 777.5, 0.5)
# ('easy,', 778, 0.5)
# ('this', 778.5, 0.5)
# ('was', 779, 0.5)
# ('@wonderful.', 779.5, 0.5)
# ('He', 780, 0.5)
# ('pulled', 780.5, 0.5)
# ('his', 781, 0.5)
# ('broomstick', 781.5, 0.5)
# ('up', 782, 0.5)
# ('a', 782.5, 0.5)
# ('little', 783, 0.5)
# ('to', 783.5, 0.5)
# ('take', 784, 0.5)
# ('it', 784.5, 0.5)
# ('even', 785, 0.5)
# ('higher,', 785.5, 0.5)
# ('and', 786, 0.5)
# ('heard', 786.5, 0.5)
# ('screams', 787, 0.5)
# ('and', 787.5, 0.5)
# ('gasps', 788, 0.5)
# ('of', 788.5, 0.5)
# ('girls', 789, 0.5)
# ('back', 789.5, 0.5)
# ('on', 790, 0.5)
# ('the', 790.5, 0.5)
# ('ground', 791, 0.5)
# ('and', 791.5, 0.5)
# ('an', 792, 0.5)
# ('admiring', 792.5, 0.5)
# ('whoop', 793, 0.5)
# ('from', 793.5, 0.5)
# ('Ron.', 794, 0.5)
# ('+', 794.5, 0.5)
# ('He', 795, 0.5)
# ('turned', 795.5, 0.5)
# ('his', 796, 0.5)
# ('broomstick', 796.5, 0.5)
# ('sharply', 797, 0.5)
# ('to', 797.5, 0.5)
# ('face', 798, 0.5)
# ('Malfoy', 798.5, 0.5)
# ('in', 799, 0.5)
# ('midair.', 799.5, 0.5)
# ('+', 800, 0.5)
# ('Malfoy', 800.5, 0.5)
# ('looked', 801, 0.5)
# ('stunned.', 801.5, 0.5)
# ('"Give', 802, 0.5)
# ('it', 802.5, 0.5)
# ('here,"', 803, 0.5)
# ('Harry', 803.5, 0.5)
# ('called,', 804, 0.5)
# ('"or', 804.5, 0.5)
# ("I'll", 805, 0.5)
# ('knock', 805.5, 0.5)
# ('you', 806, 0.5)
# ('off', 806.5, 0.5)
# ('that', 807, 0.5)
# ('broom!"', 807.5, 0.5)
# ('+', 808, 0.5)
# ('"Oh,', 808.5, 0.5)
# ('yeah?"', 809, 0.5)
# ('said', 809.5, 0.5)
# ('Malfoy,', 810, 0.5)
# ('trying', 810.5, 0.5)
# ('to', 811, 0.5)
# ('sneer,', 811.5, 0.5)
# ('but', 812, 0.5)
# ('looking', 812.5, 0.5)
# ('worried.', 813, 0.5)
# ('+', 813.5, 0.5)
# ('Harry', 814, 0.5)
# ('knew,', 814.5, 0.5)
# ('somehow,', 815, 0.5)
# ('what', 815.5, 0.5)
# ('to', 816, 0.5)
# ('do.', 816.5, 0.5)
# ('He', 817, 0.5)
# ('leaned', 817.5, 0.5)
# ('forward', 818, 0.5)
# ('and', 818.5, 0.5)
# ('grasped', 819, 0.5)
# ('the', 819.5, 0.5)
# ('broom', 820, 0.5)
# ('tightly', 820.5, 0.5)
# ('in', 821, 0.5)
# ('both', 821.5, 0.5)
# ('hands,', 822, 0.5)
# ('and', 822.5, 0.5)
# ('it', 823, 0.5)
# ('shot', 823.5, 0.5)
# ('toward', 824, 0.5)
# ('Malfoy', 824.5, 0.5)
# ('like', 825, 0.5)
# ('a', 825.5, 0.5)
# ('javelin.', 826, 0.5)
# ('Malfoy', 826.5, 0.5)
# ('only', 827, 0.5)
# ('just', 827.5, 0.5)
# ('got', 828, 0.5)
# ('out', 828.5, 0.5)
# ('of', 829, 0.5)
# ('the', 829.5, 0.5)
# ('way', 830, 0.5)
# ('in', 830.5, 0.5)
# ('time;', 831, 0.5)
# ('Harry', 831.5, 0.5)
# ('made', 832, 0.5)
# ('a', 832.5, 0.5)
# ('sharp', 833, 0.5)
# ('about-face', 833.5, 0.5)
# ('and', 834, 0.5)
# ('held', 834.5, 0.5)
# ('the', 835, 0.5)
# ('broom', 835.5, 0.5)
# ('steady.', 836, 0.5)
# ('A', 836.5, 0.5)
# ('few', 837, 0.5)
# ('people', 837.5, 0.5)
# ('below', 838, 0.5)
# ('were', 838.5, 0.5)
# ('clapping.', 839, 0.5)
# ('+', 839.5, 0.5)
# ('"No', 840, 0.5)
# ('Crabbe', 840.5, 0.5)
# ('and', 841, 0.5)
# ('Goyle', 841.5, 0.5)
# ('up', 842, 0.5)
# ('here', 842.5, 0.5)
# ('to', 843, 0.5)
# ('save', 843.5, 0.5)
# ('your', 844, 0.5)
# ('neck,', 844.5, 0.5)
# ('Malfoy,"', 845, 0.5)
# ('Harry', 845.5, 0.5)
# ('called.', 846, 0.5)
# ('+', 846.5, 0.5)
# ('The', 847, 0.5)
# ('same', 847.5, 0.5)
# ('thought', 848, 0.5)
# ('seemed', 848.5, 0.5)
# ('to', 849, 0.5)
# ('have', 849.5, 0.5)
# ('struck', 850, 0.5)
# ('Malfoy.', 850.5, 0.5)
# ('+', 851, 0.5)
# ('"Catch', 851.5, 0.5)
# ('it', 852, 0.5)
# ('if', 852.5, 0.5)
# ('you', 853, 0.5)
# ('can,', 853.5, 0.5)
# ('then!"', 854, 0.5)
# ('he', 854.5, 0.5)
# ('shouted,', 855, 0.5)
# ('and', 855.5, 0.5)
# ('he', 856, 0.5)
# ('threw', 856.5, 0.5)
# ('the', 857, 0.5)
# ('glass', 857.5, 0.5)
# ('ball', 858, 0.5)
# ('high', 858.5, 0.5)
# ('into', 859, 0.5)
# ('the', 859.5, 0.5)
# ('air', 860, 0.5)
# ('and', 860.5, 0.5)
# ('streaked', 861, 0.5)
# ('back', 861.5, 0.5)
# ('toward', 862, 0.5)
# ('the', 862.5, 0.5)
# ('ground.', 863, 0.5)
# ('+', 863.5, 0.5)
# ('Harry', 864, 0.5)
# ('saw,', 864.5, 0.5)
# ('as', 865, 0.5)
# ('though', 865.5, 0.5)
# ('in', 866, 0.5)
# ('slow', 866.5, 0.5)
# ('motion,', 867, 0.5)
# ('the', 867.5, 0.5)
# ('ball', 868, 0.5)
# ('rise', 868.5, 0.5)
# ('up', 869, 0.5)
# ('in', 869.5, 0.5)
# ('the', 870, 0.5)
# ('air', 870.5, 0.5)
# ('and', 871, 0.5)
# ('then', 871.5, 0.5)
# ('start', 872, 0.5)
# ('to', 872.5, 0.5)
# ('fall.', 873, 0.5)
# ('He', 873.5, 0.5)
# ('leaned', 874, 0.5)
# ('forward', 874.5, 0.5)
# ('and', 875, 0.5)
# ('pointed', 875.5, 0.5)
# ('his', 876, 0.5)
# ('broom', 876.5, 0.5)
# ('handle', 877, 0.5)
# ('down', 877.5, 0.5)
# ('--', 878, 0.5)
# ('next', 878.5, 0.5)
# ('second', 879, 0.5)
# ('he', 879.5, 0.5)
# ('was', 880, 0.5)
# ('gathering', 880.5, 0.5)
# ('speed', 881, 0.5)
# ('in', 881.5, 0.5)
# ('a', 882, 0.5)
# ('steep', 882.5, 0.5)
# ('dive,', 883, 0.5)
# ('racing', 883.5, 0.5)
# ('the', 884, 0.5)
# ('ball', 884.5, 0.5)
# ('--', 885, 0.5)
# ('wind', 885.5, 0.5)
# ('whistled', 886, 0.5)
# ('in', 886.5, 0.5)
# ('his', 887, 0.5)
# ('ears,', 887.5, 0.5)
# ('mingled', 888, 0.5)
# ('with', 888.5, 0.5)
# ('the', 889, 0.5)
# ('screams', 889.5, 0.5)
# ('of', 890, 0.5)
# ('people', 890.5, 0.5)
# ('watching', 891, 0.5)
# ('--', 891.5, 0.5)
# ('he', 892, 0.5)
# ('stretched', 892.5, 0.5)
# ('out', 893, 0.5)
# ('his', 893.5, 0.5)
# ('hand', 894, 0.5)
# ('--', 894.5, 0.5)
# ('a', 895, 0.5)
# ('foot', 895.5, 0.5)
# ('from', 896, 0.5)
# ('the', 896.5, 0.5)
# ('ground', 897, 0.5)
# ('he', 897.5, 0.5)
# ('caught', 898, 0.5)
# ('it,', 898.5, 0.5)
# ('just', 899, 0.5)
# ('in', 899.5, 0.5)
# ('time', 900, 0.5)
# ('to', 900.5, 0.5)
# ('pull', 901, 0.5)
# ('his', 901.5, 0.5)
# ('broom', 902, 0.5)
# ('straight,', 902.5, 0.5)
# ('and', 903, 0.5)
# ('he', 903.5, 0.5)
# ('toppled', 904, 0.5)
# ('gently', 904.5, 0.5)
# ('onto', 905, 0.5)
# ('the', 905.5, 0.5)
# ('grass', 906, 0.5)
# ('with', 906.5, 0.5)
# ('the', 907, 0.5)
# ('Remembrall', 907.5, 0.5)
# ('clutched', 908, 0.5)
# ('safely', 908.5, 0.5)
# ('in', 909, 0.5)
# ('his', 909.5, 0.5)
# ('fist.', 910, 0.5)
# ('+', 910.5, 0.5)
# ('"HARRY', 911, 0.5)
# ('POTTER!"', 911.5, 0.5)
# ('+', 912, 0.5)
# ('His', 912.5, 0.5)
# ('heart', 913, 0.5)
# ('sank', 913.5, 0.5)
# ('faster', 914, 0.5)
# ('than', 914.5, 0.5)
# ("he'd", 915, 0.5)
# ('just', 915.5, 0.5)
# ('dived.', 916, 0.5)
# ('Professor', 916.5, 0.5)
# ('McGonagall', 917, 0.5)
# ('was', 917.5, 0.5)
# ('running', 918, 0.5)
# ('toward', 918.5, 0.5)
# ('them.', 919, 0.5)
# ('He', 919.5, 0.5)
# ('got', 920, 0.5)
# ('to', 920.5, 0.5)
# ('his', 921, 0.5)
# ('feet,', 921.5, 0.5)
# ('trembling.', 922, 0.5)
# ('+', 922.5, 0.5)
# ('@"Never', 923, 0.5)
# ('--', 923.5, 0.5)
# ('in', 924, 0.5)
# ('all', 924.5, 0.5)
# ('my', 925, 0.5)
# ('time', 925.5, 0.5)
# ('at', 926, 0.5)
# ('Hogwarts', 926.5, 0.5)
# ('--"', 927, 0.5)
# ('Professor', 927.5, 0.5)
# ('McGonagall', 928, 0.5)
# ('was', 928.5, 0.5)
# ('almost', 929, 0.5)
# ('speechless', 929.5, 0.5)
# ('with', 930, 0.5)
# ('shock,', 930.5, 0.5)
# ('and', 931, 0.5)
# ('her', 931.5, 0.5)
# ('glasses', 932, 0.5)
# ('flashed', 932.5, 0.5)
# ('furiously,', 933, 0.5)
# ('"--', 933.5, 0.5)
# ('how', 934, 0.5)
# ('@dare', 934.5, 0.5)
# ('you', 935, 0.5)
# ('--', 935.5, 0.5)
# ('might', 936, 0.5)
# ('have', 936.5, 0.5)
# ('broken', 937, 0.5)
# ('your', 937.5, 0.5)
# ('neck', 938, 0.5)
# ('--"', 938.5, 0.5)
# ('+', 939, 0.5)
# ('"It', 939.5, 0.5)
# ("wasn't", 940, 0.5)
# ('his', 940.5, 0.5)
# ('fault,', 941, 0.5)
# ('Professor', 941.5, 0.5)
# ('--"', 942, 0.5)
# ('+', 942.5, 0.5)
# ('"Be', 943, 0.5)
# ('quiet,', 943.5, 0.5)
# ('Miss', 944, 0.5)
# ('Patil', 944.5, 0.5)
# ('--"', 945, 0.5)
# ('+', 945.5, 0.5)
# ('"But', 946, 0.5)
# ('Malfoy', 946.5, 0.5)
# ('--"', 947, 0.5)
# ('"That\'s', 947.5, 0.5)
# ('enough,', 948, 0.5)
# ('Mr.', 948.5, 0.5)
# ('Weasley.', 949, 0.5)
# ('Potter,', 949.5, 0.5)
# ('follow', 950, 0.5)
# ('me,', 950.5, 0.5)
# ('now."', 951, 0.5)
# ('+', 951.5, 0.5)
# ('Harry', 952, 0.5)
# ('caught', 952.5, 0.5)
# ('sight', 953, 0.5)
# ('of', 953.5, 0.5)
# ('Malfoy,', 954, 0.5)
# ('Crabbe,', 954.5, 0.5)
# ('and', 955, 0.5)
# ("Goyle's", 955.5, 0.5)
# ('triumphant', 956, 0.5)
# ('faces', 956.5, 0.5)
# ('as', 957, 0.5)
# ('he', 957.5, 0.5)
# ('left,', 958, 0.5)
# ('walking', 958.5, 0.5)
# ('numbly', 959, 0.5)
# ('in', 959.5, 0.5)
# ('Professor', 960, 0.5)
# ("McGonagall's", 960.5, 0.5)
# ('wake', 961, 0.5)
# ('as', 961.5, 0.5)
# ('she', 962, 0.5)
# ('strode', 962.5, 0.5)
# ('toward', 963, 0.5)
# ('the', 963.5, 0.5)
# ('castle.', 964, 0.5)
# ('He', 964.5, 0.5)
# ('was', 965, 0.5)
# ('going', 965.5, 0.5)
# ('to', 966, 0.5)
# ('be', 966.5, 0.5)
# ('expelled,', 967, 0.5)
# ('he', 967.5, 0.5)
# ('just', 968, 0.5)
# ('knew', 968.5, 0.5)
# ('it.', 969, 0.5)
# ('He', 969.5, 0.5)
# ('wanted', 970, 0.5)
# ('to', 970.5, 0.5)
# ('say', 971, 0.5)
# ('something', 971.5, 0.5)
# ('to', 972, 0.5)
# ('defend', 972.5, 0.5)
# ('himself,', 973, 0.5)
# ('but', 973.5, 0.5)
# ('there', 974, 0.5)
# ('seemed', 974.5, 0.5)
# ('to', 975, 0.5)
# ('be', 975.5, 0.5)
# ('something', 976, 0.5)
# ('wrong', 976.5, 0.5)
# ('with', 977, 0.5)
# ('his', 977.5, 0.5)
# ('voice.', 978, 0.5)
# ('Professor', 978.5, 0.5)
# ('McGonagall', 979, 0.5)
# ('was', 979.5, 0.5)
# ('sweeping', 980, 0.5)
# ('along', 980.5, 0.5)
# ('without', 981, 0.5)
# ('even', 981.5, 0.5)
# ('looking', 982, 0.5)
# ('at', 982.5, 0.5)
# ('him;', 983, 0.5)
# ('he', 983.5, 0.5)
# ('had', 984, 0.5)
# ('to', 984.5, 0.5)
# ('jog', 985, 0.5)
# ('to', 985.5, 0.5)
# ('keep', 986, 0.5)
# ('up.', 986.5, 0.5)
# ('Now', 987, 0.5)
# ("he'd", 987.5, 0.5)
# ('done', 988, 0.5)
# ('it.', 988.5, 0.5)
# ('He', 989, 0.5)
# ("hadn't", 989.5, 0.5)
# ('even', 990, 0.5)
# ('lasted', 990.5, 0.5)
# ('two', 991, 0.5)
# ('weeks.', 991.5, 0.5)
# ("He'd", 992, 0.5)
# ('be', 992.5, 0.5)
# ('packing', 993, 0.5)
# ('his', 993.5, 0.5)
# ('bags', 994, 0.5)
# ('in', 994.5, 0.5)
# ('ten', 995, 0.5)
# ('minutes.', 995.5, 0.5)
# ('What', 996, 0.5)
# ('would', 996.5, 0.5)
# ('the', 997, 0.5)
# ('Dursleys', 997.5, 0.5)
# ('say', 998, 0.5)
# ('when', 998.5, 0.5)
# ('he', 999, 0.5)
# ('turned', 999.5, 0.5)
# ('up', 1000, 0.5)
# ('on', 1000.5, 0.5)
# ('the', 1001, 0.5)
# ('doorstep?', 1001.5, 0.5)
# ('+', 1002, 0.5)
# ('Up', 1002.5, 0.5)
# ('the', 1003, 0.5)
# ('front', 1003.5, 0.5)
# ('steps,', 1004, 0.5)
# ('up', 1004.5, 0.5)
# ('the', 1005, 0.5)
# ('marble', 1005.5, 0.5)
# ('staircase', 1006, 0.5)
# ('inside,', 1006.5, 0.5)
# ('and', 1007, 0.5)
# ('still', 1007.5, 0.5)
# ('Professor', 1008, 0.5)
# ('McGonagall', 1008.5, 0.5)
# ("didn't", 1009, 0.5)
# ('say', 1009.5, 0.5)
# ('a', 1010, 0.5)
# ('word', 1010.5, 0.5)
# ('to', 1011, 0.5)
# ('him.', 1011.5, 0.5)
# ('She', 1012, 0.5)
# ('wrenched', 1012.5, 0.5)
# ('open', 1013, 0.5)
# ('doors', 1013.5, 0.5)
# ('and', 1014, 0.5)
# ('marched', 1014.5, 0.5)
# ('along', 1015, 0.5)
# ('corridors', 1015.5, 0.5)
# ('with', 1016, 0.5)
# ('Harry', 1016.5, 0.5)
# ('trotting', 1017, 0.5)
# ('miserably', 1017.5, 0.5)
# ('behind', 1018, 0.5)
# ('her.', 1018.5, 0.5)
# ('Maybe', 1019, 0.5)
# ('she', 1019.5, 0.5)
# ('was', 1020, 0.5)
# ('taking', 1020.5, 0.5)
# ('him', 1021, 0.5)
# ('to', 1021.5, 0.5)
# ('Dumbledore.', 1022, 0.5)
# ('He', 1022.5, 0.5)
# ('thought', 1023, 0.5)
# ('of', 1023.5, 0.5)
# ('Hagrid,', 1024, 0.5)
# ('expelled', 1024.5, 0.5)
# ('but', 1025, 0.5)
# ('allowed', 1025.5, 0.5)
# ('to', 1026, 0.5)
# ('stay', 1026.5, 0.5)
# ('on', 1027, 0.5)
# ('as', 1027.5, 0.5)
# ('gamekeeper.', 1028, 0.5)
# ('Perhaps', 1028.5, 0.5)
# ('he', 1029, 0.5)
# ('could', 1029.5, 0.5)
# ('be', 1030, 0.5)
# ("Hagrid's", 1030.5, 0.5)
# ('assistant.', 1031, 0.5)
# ('His', 1031.5, 0.5)
# ('stomach', 1032, 0.5)
# ('twisted', 1032.5, 0.5)
# ('as', 1033, 0.5)
# ('he', 1033.5, 0.5)
# ('imagined', 1034, 0.5)
# ('it,', 1034.5, 0.5)
# ('watching', 1035, 0.5)
# ('Ron', 1035.5, 0.5)
# ('and', 1036, 0.5)
# ('the', 1036.5, 0.5)
# ('others', 1037, 0.5)
# ('becoming', 1037.5, 0.5)
# ('wizards', 1038, 0.5)
# ('while', 1038.5, 0.5)
# ('he', 1039, 0.5)
# ('stumped', 1039.5, 0.5)
# ('around', 1040, 0.5)
# ('the', 1040.5, 0.5)
# ('grounds', 1041, 0.5)
# ('carrying', 1041.5, 0.5)
# ("Hagrid's", 1042, 0.5)
# ('bag.', 1042.5, 0.5)
# ('+', 1043, 0.5)
# ('Professor', 1043.5, 0.5)
# ('McGonagall', 1044, 0.5)
# ('stopped', 1044.5, 0.5)
# ('outside', 1045, 0.5)
# ('a', 1045.5, 0.5)
# ('classroom.', 1046, 0.5)
# ('She', 1046.5, 0.5)
# ('opened', 1047, 0.5)
# ('the', 1047.5, 0.5)
# ('door', 1048, 0.5)
# ('and', 1048.5, 0.5)
# ('poked', 1049, 0.5)
# ('her', 1049.5, 0.5)
# ('head', 1050, 0.5)
# ('inside.', 1050.5, 0.5)
# ('+', 1051, 0.5)
# ('"Excuse', 1051.5, 0.5)
# ('me,', 1052, 0.5)
# ('Professor', 1052.5, 0.5)
# ('Flitwick,', 1053, 0.5)
# ('could', 1053.5, 0.5)
# ('I', 1054, 0.5)
# ('borrow', 1054.5, 0.5)
# ('Wood', 1055, 0.5)
# ('for', 1055.5, 0.5)
# ('a', 1056, 0.5)
# ('moment?"', 1056.5, 0.5)
# ('+', 1057, 0.5)
# ('Wood?', 1057.5, 0.5)
# ('thought', 1058, 0.5)
# ('Harry,', 1058.5, 0.5)
# ('bewildered;', 1059, 0.5)
# ('was', 1059.5, 0.5)
# ('Wood', 1060, 0.5)
# ('a', 1060.5, 0.5)
# ('cane', 1061, 0.5)
# ('she', 1061.5, 0.5)
# ('was', 1062, 0.5)
# ('going', 1062.5, 0.5)
# ('to', 1063, 0.5)
# ('use', 1063.5, 0.5)
# ('on', 1064, 0.5)
# ('him?', 1064.5, 0.5)
# ('But', 1065, 0.5)
# ('Wood', 1065.5, 0.5)
# ('turned', 1066, 0.5)
# ('out', 1066.5, 0.5)
# ('to', 1067, 0.5)
# ('be', 1067.5, 0.5)
# ('a', 1068, 0.5)
# ('person,', 1068.5, 0.5)
# ('a', 1069, 0.5)
# ('burly', 1069.5, 0.5)
# ('fifth-year', 1070, 0.5)
# ('boy', 1070.5, 0.5)
# ('who', 1071, 0.5)
# ('came', 1071.5, 0.5)
# ('out', 1072, 0.5)
# ('of', 1072.5, 0.5)
# ("Flitwick's", 1073, 0.5)
# ('class', 1073.5, 0.5)
# ('looking', 1074, 0.5)
# ('confused.', 1074.5, 0.5)
# ('+', 1075, 0.5)
# ('"Follow', 1075.5, 0.5)
# ('me,', 1076, 0.5)
# ('you', 1076.5, 0.5)
# ('two,"', 1077, 0.5)
# ('said', 1077.5, 0.5)
# ('Professor', 1078, 0.5)
# ('McGonagall,', 1078.5, 0.5)
# ('and', 1079, 0.5)
# ('they', 1079.5, 0.5)
# ('marched', 1080, 0.5)
# ('on', 1080.5, 0.5)
# ('up', 1081, 0.5)
# ('the', 1081.5, 0.5)
# ('corridor,', 1082, 0.5)
# ('Wood', 1082.5, 0.5)
# ('looking', 1083, 0.5)
# ('curiously', 1083.5, 0.5)
# ('at', 1084, 0.5)
# ('Harry.', 1084.5, 0.5)
# ('+', 1085, 0.5)
# ('"In', 1085.5, 0.5)
# ('here."', 1086, 0.5)
# ('+', 1086.5, 0.5)
# ('Professor', 1087, 0.5)
# ('McGonagall', 1087.5, 0.5)
# ('pointed', 1088, 0.5)
# ('them', 1088.5, 0.5)
# ('into', 1089, 0.5)
# ('a', 1089.5, 0.5)
# ('classroom', 1090, 0.5)
# ('that', 1090.5, 0.5)
# ('was', 1091, 0.5)
# ('empty', 1091.5, 0.5)
# ('except', 1092, 0.5)
# ('for', 1092.5, 0.5)
# ('Peeves,', 1093, 0.5)
# ('who', 1093.5, 0.5)
# ('was', 1094, 0.5)
# ('busy', 1094.5, 0.5)
# ('writing', 1095, 0.5)
# ('rude', 1095.5, 0.5)
# ('words', 1096, 0.5)
# ('on', 1096.5, 0.5)
# ('the', 1097, 0.5)
# ('blackboard.', 1097.5, 0.5)
# ('+', 1098, 0.5)
# ('"Out,', 1098.5, 0.5)
# ('Peeves!"', 1099, 0.5)
# ('she', 1099.5, 0.5)
# ('barked.', 1100, 0.5)
# ('Peeves', 1100.5, 0.5)
# ('threw', 1101, 0.5)
# ('the', 1101.5, 0.5)
# ('chalk', 1102, 0.5)
# ('into', 1102.5, 0.5)
# ('a', 1103, 0.5)
# ('bin,', 1103.5, 0.5)
# ('which', 1104, 0.5)
# ('clanged', 1104.5, 0.5)
# ('loudly,', 1105, 0.5)
# ('and', 1105.5, 0.5)
# ('he', 1106, 0.5)
# ('swooped', 1106.5, 0.5)
# ('out', 1107, 0.5)
# ('cursing.', 1107.5, 0.5)
# ('Professor', 1108, 0.5)
# ('McGonagall', 1108.5, 0.5)
# ('slammed', 1109, 0.5)
# ('the', 1109.5, 0.5)
# ('door', 1110, 0.5)
# ('behind', 1110.5, 0.5)
# ('him', 1111, 0.5)
# ('and', 1111.5, 0.5)
# ('turned', 1112, 0.5)
# ('to', 1112.5, 0.5)
# ('face', 1113, 0.5)
# ('the', 1113.5, 0.5)
# ('two', 1114, 0.5)
# ('boys.', 1114.5, 0.5)
# ('+', 1115, 0.5)
# ('"Potter,', 1115.5, 0.5)
# ('this', 1116, 0.5)
# ('is', 1116.5, 0.5)
# ('Oliver', 1117, 0.5)
# ('Wood.', 1117.5, 0.5)
# ('Wood', 1118, 0.5)
# ('--', 1118.5, 0.5)
# ("I've", 1119, 0.5)
# ('found', 1119.5, 0.5)
# ('you', 1120, 0.5)
# ('a', 1120.5, 0.5)
# ('Seeker."', 1121, 0.5)
# ('+', 1121.5, 0.5)
# ("Wood's", 1122, 0.5)
# ('expression', 1122.5, 0.5)
# ('changed', 1123, 0.5)
# ('from', 1123.5, 0.5)
# ('puzzlement', 1124, 0.5)
# ('to', 1124.5, 0.5)
# ('delight.', 1125, 0.5)
# ('+', 1125.5, 0.5)
# ('"Are', 1126, 0.5)
# ('you', 1126.5, 0.5)
# ('serious,', 1127, 0.5)
# ('Professor?"', 1127.5, 0.5)
# ('+', 1128, 0.5)
# ('"Absolutely,"', 1128.5, 0.5)
# ('said', 1129, 0.5)
# ('Professor', 1129.5, 0.5)
# ('McGonagall', 1130, 0.5)
# ('crisply.', 1130.5, 0.5)
# ('"The', 1131, 0.5)
# ("boy's", 1131.5, 0.5)
# ('a', 1132, 0.5)
# ('natural.', 1132.5, 0.5)
# ("I've", 1133, 0.5)
# ('never', 1133.5, 0.5)
# ('seen', 1134, 0.5)
# ('anything', 1134.5, 0.5)
# ('like', 1135, 0.5)
# ('it.', 1135.5, 0.5)
# ('Was', 1136, 0.5)
# ('that', 1136.5, 0.5)
# ('your', 1137, 0.5)
# ('first', 1137.5, 0.5)
# ('time', 1138, 0.5)
# ('on', 1138.5, 0.5)
# ('a', 1139, 0.5)
# ('broomstick,', 1139.5, 0.5)
# ('Potter?"', 1140, 0.5)
# ('+', 1140.5, 0.5)
# ('Harry', 1141, 0.5)
# ('nodded', 1141.5, 0.5)
# ('silently.', 1142, 0.5)
# ('He', 1142.5, 0.5)
# ("didn't", 1143, 0.5)
# ('have', 1143.5, 0.5)
# ('a', 1144, 0.5)
# ('clue', 1144.5, 0.5)
# ('what', 1145, 0.5)
# ('was', 1145.5, 0.5)
# ('going', 1146, 0.5)
# ('on,', 1146.5, 0.5)
# ('but', 1147, 0.5)
# ('he', 1147.5, 0.5)
# ("didn't", 1148, 0.5)
# ('seem', 1148.5, 0.5)
# ('to', 1149, 0.5)
# ('be', 1149.5, 0.5)
# ('being', 1150, 0.5)
# ('expelled,', 1150.5, 0.5)
# ('and', 1151, 0.5)
# ('some', 1151.5, 0.5)
# ('of', 1152, 0.5)
# ('the', 1152.5, 0.5)
# ('feeling', 1153, 0.5)
# ('started', 1153.5, 0.5)
# ('coming', 1154, 0.5)
# ('back', 1154.5, 0.5)
# ('to', 1155, 0.5)
# ('his', 1155.5, 0.5)
# ('legs.', 1156, 0.5)
# ('+', 1156.5, 0.5)
# ('"He', 1157, 0.5)
# ('caught', 1157.5, 0.5)
# ('that', 1158, 0.5)
# ('thing', 1158.5, 0.5)
# ('in', 1159, 0.5)
# ('his', 1159.5, 0.5)
# ('hand', 1160, 0.5)
# ('after', 1160.5, 0.5)
# ('a', 1161, 0.5)
# ('fifty-foot', 1161.5, 0.5)
# ('dive,"', 1162, 0.5)
# ('Professor', 1162.5, 0.5)
# ('McGonagall', 1163, 0.5)
# ('told', 1163.5, 0.5)
# ('Wood.', 1164, 0.5)
# ('"Didn\'t', 1164.5, 0.5)
# ('even', 1165, 0.5)
# ('scratch', 1165.5, 0.5)
# ('himself.', 1166, 0.5)
# ('Charlie', 1166.5, 0.5)
# ('Weasley', 1167, 0.5)
# ("couldn't", 1167.5, 0.5)
# ('have', 1168, 0.5)
# ('done', 1168.5, 0.5)
# ('it."', 1169, 0.5)
# ('+', 1169.5, 0.5)
# ('Wood', 1170, 0.5)
# ('was', 1170.5, 0.5)
# ('now', 1171, 0.5)
# ('looking', 1171.5, 0.5)
# ('as', 1172, 0.5)
# ('though', 1172.5, 0.5)
# ('all', 1173, 0.5)
# ('his', 1173.5, 0.5)
# ('dreams', 1174, 0.5)
# ('had', 1174.5, 0.5)
# ('come', 1175, 0.5)
# ('true', 1175.5, 0.5)
# ('at', 1176, 0.5)
# ('once.', 1176.5, 0.5)
# ('+', 1177, 0.5)
# ('"Ever', 1177.5, 0.5)
# ('seen', 1178, 0.5)
# ('a', 1178.5, 0.5)
# ('game', 1179, 0.5)
# ('of', 1179.5, 0.5)
# ('Quidditch,', 1180, 0.5)
# ('Potter?"', 1180.5, 0.5)
# ('he', 1181, 0.5)
# ('asked', 1181.5, 0.5)
# ('excitedly.', 1182, 0.5)
# ('+', 1182.5, 0.5)
# ('"Wood\'s', 1183, 0.5)
# ('captain', 1183.5, 0.5)
# ('of', 1184, 0.5)
# ('the', 1184.5, 0.5)
# ('Gryffindor', 1185, 0.5)
# ('team,"', 1185.5, 0.5)
# ('Professor', 1186, 0.5)
# ('McGonagall', 1186.5, 0.5)
# ('explained.', 1187, 0.5)
# ('+', 1187.5, 0.5)
# ('"He\'s', 1188, 0.5)
# ('just', 1188.5, 0.5)
# ('the', 1189, 0.5)
# ('build', 1189.5, 0.5)
# ('for', 1190, 0.5)
# ('a', 1190.5, 0.5)
# ('Seeker,', 1191, 0.5)
# ('too,"', 1191.5, 0.5)
# ('said', 1192, 0.5)
# ('Wood,', 1192.5, 0.5)
# ('now', 1193, 0.5)
# ('walking', 1193.5, 0.5)
# ('around', 1194, 0.5)
# ('Harry', 1194.5, 0.5)
# ('and', 1195, 0.5)
# ('staring', 1195.5, 0.5)
# ('at', 1196, 0.5)
# ('him.', 1196.5, 0.5)
# ('"Light', 1197, 0.5)
# ('--', 1197.5, 0.5)
# ('speedy', 1198, 0.5)
# ('--', 1198.5, 0.5)
# ("we'll", 1199, 0.5)
# ('have', 1199.5, 0.5)
# ('to', 1200, 0.5)
# ('get', 1200.5, 0.5)
# ('him', 1201, 0.5)
# ('a', 1201.5, 0.5)
# ('decent', 1202, 0.5)
# ('broom,', 1202.5, 0.5)
# ('Professor', 1203, 0.5)
# ('--', 1203.5, 0.5)
# ('a', 1204, 0.5)
# ('Nimbus', 1204.5, 0.5)
# ('Two', 1205, 0.5)
# ('Thousand', 1205.5, 0.5)
# ('or', 1206, 0.5)
# ('a', 1206.5, 0.5)
# ('Cleansweep', 1207, 0.5)
# ('Seven,', 1207.5, 0.5)
# ...
# ('where', 2322.5, 0.5)
# ('they', 2323, 0.5)
# ('slammed', 2323.5, 0.5)
# ('into', 2324, 0.5)
# ('a', 2324.5, 0.5)
# ('door', 2325, 0.5)
# ('--', 2325.5, 0.5)
# ('and', 2326, 0.5)
# ('it', 2326.5, 0.5)
# ('was', 2327, 0.5)
# ('locked.', 2327.5, 0.5)
# ('+', 2328, 0.5)
# ('"This', 2328.5, 0.5)
# ('is', 2329, 0.5)
# ('it!"', 2329.5, 0.5)
# ('Ron', 2330, 0.5)
# ('moaned,', 2330.5, 0.5)
# ('as', 2331, 0.5)
# ('they', 2331.5, 0.5)
# ('pushed', 2332, 0.5)
# ('helplessly', 2332.5, 0.5)
# ('at', 2333, 0.5)
# ('the', 2333.5, 0.5)
# ('door,', 2334, 0.5)
# ('"We\'re', 2334.5, 0.5)
# ('done', 2335, 0.5)
# ('for!', 2335.5, 0.5)
# ('This', 2336, 0.5)
# ('is', 2336.5, 0.5)
# ('the', 2337, 0.5)
# ('end!"', 2337.5, 0.5)
# ('+', 2338, 0.5)
# ('They', 2338.5, 0.5)
# ('could', 2339, 0.5)
# ('hear', 2339.5, 0.5)
# ('footsteps,', 2340, 0.5)
# ('Filch', 2340.5, 0.5)
# ('running', 2341, 0.5)
# ('as', 2341.5, 0.5)
# ('fast', 2342, 0.5)
# ('as', 2342.5, 0.5)
# ('he', 2343, 0.5)
# ('could', 2343.5, 0.5)
# ('toward', 2344, 0.5)
# ("Peeves's", 2344.5, 0.5)
# ('shouts.', 2345, 0.5)
# ('+', 2345.5, 0.5)
# ('"Oh,', 2346, 0.5)
# ('move', 2346.5, 0.5)
# ('over,"', 2347, 0.5)
# ('Hermione', 2347.5, 0.5)
# ('snarled.', 2348, 0.5)
# ('She', 2348.5, 0.5)
# ('grabbed', 2349, 0.5)
# ("Harry's", 2349.5, 0.5)
# ('wand,', 2350, 0.5)
# ('tapped', 2350.5, 0.5)
# ('the', 2351, 0.5)
# ('lock,', 2351.5, 0.5)
# ('and', 2352, 0.5)
# ('whispered,', 2352.5, 0.5)
# ('@"Alohomora!"', 2353, 0.5)
# ('+', 2353.5, 0.5)
# ('The', 2354, 0.5)
# ('lock', 2354.5, 0.5)
# ('clicked', 2355, 0.5)
# ('and', 2355.5, 0.5)
# ('the', 2356, 0.5)
# ('door', 2356.5, 0.5)
# ('swung', 2357, 0.5)
# ('open', 2357.5, 0.5)
# ('--', 2358, 0.5)
# ('they', 2358.5, 0.5)
# ('piled', 2359, 0.5)
# ('through', 2359.5, 0.5)
# ('it,', 2360, 0.5)
# ('shut', 2360.5, 0.5)
# ('it', 2361, 0.5)
# ('quickly,', 2361.5, 0.5)
# ('and', 2362, 0.5)
# ('pressed', 2362.5, 0.5)
# ('their', 2363, 0.5)
# ('ears', 2363.5, 0.5)
# ('against', 2364, 0.5)
# ('it,', 2364.5, 0.5)
# ('listening.', 2365, 0.5)
# ('+', 2365.5, 0.5)
# ('"Which', 2366, 0.5)
# ('way', 2366.5, 0.5)
# ('did', 2367, 0.5)
# ('they', 2367.5, 0.5)
# ('go,', 2368, 0.5)
# ('Peeves?"', 2368.5, 0.5)
# ('Filch', 2369, 0.5)
# ('was', 2369.5, 0.5)
# ('saying.', 2370, 0.5)
# ('"Quick,', 2370.5, 0.5)
# ('tell', 2371, 0.5)
# ('me."', 2371.5, 0.5)
# ('"Say', 2372, 0.5)
# ('\'please.\'"', 2372.5, 0.5)
# ('+', 2373, 0.5)
# ('"Don\'t', 2373.5, 0.5)
# ('mess', 2374, 0.5)
# ('with', 2374.5, 0.5)
# ('me,', 2375, 0.5)
# ('Peeves,', 2375.5, 0.5)
# ('now', 2376, 0.5)
# ('@where', 2376.5, 0.5)
# ('@did', 2377, 0.5)
# ('@they', 2377.5, 0.5)
# ('@go?"', 2378, 0.5)
# ('"Shan\'t', 2378.5, 0.5)
# ('say', 2379, 0.5)
# ('nothing', 2379.5, 0.5)
# ('if', 2380, 0.5)
# ('you', 2380.5, 0.5)
# ("don't", 2381, 0.5)
# ('say', 2381.5, 0.5)
# ('please,"', 2382, 0.5)
# ('said', 2382.5, 0.5)
# ('Peeves', 2383, 0.5)
# ('in', 2383.5, 0.5)
# ('his', 2384, 0.5)
# ('annoying', 2384.5, 0.5)
# ('singsong', 2385, 0.5)
# ('voice.', 2385.5, 0.5)
# ('"All', 2386, 0.5)
# ('right', 2386.5, 0.5)
# ('--', 2387, 0.5)
# ('@please."', 2387.5, 0.5)
# ('+', 2388, 0.5)
# ('"NOTHING!', 2388.5, 0.5)
# ('Ha', 2389, 0.5)
# ('haaa!', 2389.5, 0.5)
# ('Told', 2390, 0.5)
# ('you', 2390.5, 0.5)
# ('I', 2391, 0.5)
# ("wouldn't", 2391.5, 0.5)
# ('say', 2392, 0.5)
# ('nothing', 2392.5, 0.5)
# ('if', 2393, 0.5)
# ('you', 2393.5, 0.5)
# ("didn't", 2394, 0.5)
# ('say', 2394.5, 0.5)
# ('please!', 2395, 0.5)
# ('Ha', 2395.5, 0.5)
# ('ha!', 2396, 0.5)
# ('Haaaaaa!"', 2396.5, 0.5)
# ('And', 2397, 0.5)
# ('they', 2397.5, 0.5)
# ('heard', 2398, 0.5)
# ('the', 2398.5, 0.5)
# ('sound', 2399, 0.5)
# ('of', 2399.5, 0.5)
# ('Peeves', 2400, 0.5)
# ('whooshing', 2400.5, 0.5)
# ('away', 2401, 0.5)
# ('and', 2401.5, 0.5)
# ('Filch', 2402, 0.5)
# ('cursing', 2402.5, 0.5)
# ('in', 2403, 0.5)
# ('rage.', 2403.5, 0.5)
# ('+', 2404, 0.5)
# ('"He', 2404.5, 0.5)
# ('thinks', 2405, 0.5)
# ('this', 2405.5, 0.5)
# ('door', 2406, 0.5)
# ('is', 2406.5, 0.5)
# ('locked,"', 2407, 0.5)
# ('Harry', 2407.5, 0.5)
# ('whispered.', 2408, 0.5)
# ('"I', 2408.5, 0.5)
# ('think', 2409, 0.5)
# ("we'll", 2409.5, 0.5)
# ('be', 2410, 0.5)
# ('okay', 2410.5, 0.5)
# ('--', 2411, 0.5)
# ('get', 2411.5, 0.5)
# ('@off,', 2412, 0.5)
# ('Neville!"', 2412.5, 0.5)
# ('For', 2413, 0.5)
# ('Neville', 2413.5, 0.5)
# ('had', 2414, 0.5)
# ('been', 2414.5, 0.5)
# ('tugging', 2415, 0.5)
# ('on', 2415.5, 0.5)
# ('the', 2416, 0.5)
# ('sleeve', 2416.5, 0.5)
# ('of', 2417, 0.5)
# ("Harry's", 2417.5, 0.5)
# ('bathrobe', 2418, 0.5)
# ('for', 2418.5, 0.5)
# ('the', 2419, 0.5)
# ('last', 2419.5, 0.5)
# ('minute.', 2420, 0.5)
# ('@"What?"', 2420.5, 0.5)
# ('+', 2421, 0.5)
# ('Harry', 2421.5, 0.5)
# ('turned', 2422, 0.5)
# ('around', 2422.5, 0.5)
# ('--', 2423, 0.5)
# ('and', 2423.5, 0.5)
# ('saw,', 2424, 0.5)
# ('quite', 2424.5, 0.5)
# ('clearly,', 2425, 0.5)
# ('what.', 2425.5, 0.5)
# ('For', 2426, 0.5)
# ('a', 2426.5, 0.5)
# ('moment,', 2427, 0.5)
# ('he', 2427.5, 0.5)
# ('was', 2428, 0.5)
# ('sure', 2428.5, 0.5)
# ("he'd", 2429, 0.5)
# ('walked', 2429.5, 0.5)
# ('into', 2430, 0.5)
# ('a', 2430.5, 0.5)
# ('nightmare', 2431, 0.5)
# ('--', 2431.5, 0.5)
# ('this', 2432, 0.5)
# ('was', 2432.5, 0.5)
# ('too', 2433, 0.5)
# ('much,', 2433.5, 0.5)
# ('on', 2434, 0.5)
# ('top', 2434.5, 0.5)
# ('of', 2435, 0.5)
# ('everything', 2435.5, 0.5)
# ('that', 2436, 0.5)
# ('had', 2436.5, 0.5)
# ('happened', 2437, 0.5)
# ('so', 2437.5, 0.5)
# ('far.', 2438, 0.5)
# ('+', 2438.5, 0.5)
# ('They', 2439, 0.5)
# ("weren't", 2439.5, 0.5)
# ('in', 2440, 0.5)
# ('a', 2440.5, 0.5)
# ('room,', 2441, 0.5)
# ('as', 2441.5, 0.5)
# ('he', 2442, 0.5)
# ('had', 2442.5, 0.5)
# ('supposed.', 2443, 0.5)
# ('They', 2443.5, 0.5)
# ('were', 2444, 0.5)
# ('in', 2444.5, 0.5)
# ('a', 2445, 0.5)
# ('corridor.', 2445.5, 0.5)
# ('The', 2446, 0.5)
# ('forbidden', 2446.5, 0.5)
# ('corridor', 2447, 0.5)
# ('on', 2447.5, 0.5)
# ('the', 2448, 0.5)
# ('third', 2448.5, 0.5)
# ('floor.', 2449, 0.5)
# ('And', 2449.5, 0.5)
# ('now', 2450, 0.5)
# ('they', 2450.5, 0.5)
# ('knew', 2451, 0.5)
# ('why', 2451.5, 0.5)
# ('it', 2452, 0.5)
# ('was', 2452.5, 0.5)
# ('forbidden.', 2453, 0.5)
# ('+', 2453.5, 0.5)
# ('They', 2454, 0.5)
# ('were', 2454.5, 0.5)
# ('looking', 2455, 0.5)
# ('straight', 2455.5, 0.5)
# ('into', 2456, 0.5)
# ('the', 2456.5, 0.5)
# ('eyes', 2457, 0.5)
# ('of', 2457.5, 0.5)
# ('a', 2458, 0.5)
# ('monstrous', 2458.5, 0.5)
# ('dog,', 2459, 0.5)
# ('a', 2459.5, 0.5)
# ('dog', 2460, 0.5)
# ('that', 2460.5, 0.5)
# ('filled', 2461, 0.5)
# ('the', 2461.5, 0.5)
# ('whole', 2462, 0.5)
# ('space', 2462.5, 0.5)
# ('between', 2463, 0.5)
# ('ceiling', 2463.5, 0.5)
# ('and', 2464, 0.5)
# ('floor.', 2464.5, 0.5)
# ('It', 2465, 0.5)
# ('had', 2465.5, 0.5)
# ('three', 2466, 0.5)
# ('heads.', 2466.5, 0.5)
# ('Three', 2467, 0.5)
# ('pairs', 2467.5, 0.5)
# ('of', 2468, 0.5)
# ('rolling,', 2468.5, 0.5)
# ('mad', 2469, 0.5)
# ('eyes;', 2469.5, 0.5)
# ('three', 2470, 0.5)
# ('noses,', 2470.5, 0.5)
# ('twitching', 2471, 0.5)
# ('and', 2471.5, 0.5)
# ('quivering', 2472, 0.5)
# ('in', 2472.5, 0.5)
# ('their', 2473, 0.5)
# ('direction;', 2473.5, 0.5)
# ('three', 2474, 0.5)
# ('drooling', 2474.5, 0.5)
# ('mouths,', 2475, 0.5)
# ('saliva', 2475.5, 0.5)
# ('hanging', 2476, 0.5)
# ('in', 2476.5, 0.5)
# ('slippery', 2477, 0.5)
# ('ropes', 2477.5, 0.5)
# ('from', 2478, 0.5)
# ('yellowish', 2478.5, 0.5)
# ('fangs.', 2479, 0.5)
# ('+', 2479.5, 0.5)
# ('It', 2480, 0.5)
# ('was', 2480.5, 0.5)
# ('standing', 2481, 0.5)
# ('quite', 2481.5, 0.5)
# ('still,', 2482, 0.5)
# ('all', 2482.5, 0.5)
# ('six', 2483, 0.5)
# ('eyes', 2483.5, 0.5)
# ('staring', 2484, 0.5)
# ('at', 2484.5, 0.5)
# ('them,', 2485, 0.5)
# ('and', 2485.5, 0.5)
# ('Harry', 2486, 0.5)
# ('knew', 2486.5, 0.5)
# ('that', 2487, 0.5)
# ('the', 2487.5, 0.5)
# ('only', 2488, 0.5)
# ('reason', 2488.5, 0.5)
# ('they', 2489, 0.5)
# ("weren't", 2489.5, 0.5)
# ('already', 2490, 0.5)
# ('dead', 2490.5, 0.5)
# ('was', 2491, 0.5)
# ('that', 2491.5, 0.5)
# ('their', 2492, 0.5)
# ('sudden', 2492.5, 0.5)
# ('appearance', 2493, 0.5)
# ('had', 2493.5, 0.5)
# ('taken', 2494, 0.5)
# ('it', 2494.5, 0.5)
# ('by', 2495, 0.5)
# ('surprise,', 2495.5, 0.5)
# ('but', 2496, 0.5)
# ('it', 2496.5, 0.5)
# ('was', 2497, 0.5)
# ('quickly', 2497.5, 0.5)
# ('getting', 2498, 0.5)
# ('over', 2498.5, 0.5)
# ('that,', 2499, 0.5)
# ('there', 2499.5, 0.5)
# ('was', 2500, 0.5)
# ('no', 2500.5, 0.5)
# ('mistaking', 2501, 0.5)
# ('what', 2501.5, 0.5)
# ('those', 2502, 0.5)
# ('thunderous', 2502.5, 0.5)
# ('growls', 2503, 0.5)
# ('meant.', 2503.5, 0.5)
# ('+', 2504, 0.5)
# ('Harry', 2504.5, 0.5)
# ('groped', 2505, 0.5)
# ('for', 2505.5, 0.5)
# ('the', 2506, 0.5)
# ('doorknob', 2506.5, 0.5)
# ('--', 2507, 0.5)
# ('between', 2507.5, 0.5)
# ('Filch', 2508, 0.5)
# ('and', 2508.5, 0.5)
# ('death,', 2509, 0.5)
# ("he'd", 2509.5, 0.5)
# ('take', 2510, 0.5)
# ('Filch.', 2510.5, 0.5)
# ('+', 2511, 0.5)
# ('They', 2511.5, 0.5)
# ('fell', 2512, 0.5)
# ('backward', 2512.5, 0.5)
# ('--', 2513, 0.5)
# ('Harry', 2513.5, 0.5)
# ('slammed', 2514, 0.5)
# ('the', 2514.5, 0.5)
# ('door', 2515, 0.5)
# ('shut,', 2515.5, 0.5)
# ('and', 2516, 0.5)
# ('they', 2516.5, 0.5)
# ('ran,', 2517, 0.5)
# ('they', 2517.5, 0.5)
# ('almost', 2518, 0.5)
# ('flew,', 2518.5, 0.5)
# ('back', 2519, 0.5)
# ('down', 2519.5, 0.5)
# ('the', 2520, 0.5)
# ('corridor.', 2520.5, 0.5)
# ('Filch', 2521, 0.5)
# ('must', 2521.5, 0.5)
# ('have', 2522, 0.5)
# ('hurried', 2522.5, 0.5)
# ('off', 2523, 0.5)
# ('to', 2523.5, 0.5)
# ('look', 2524, 0.5)
# ('for', 2524.5, 0.5)
# ('them', 2525, 0.5)
# ('somewhere', 2525.5, 0.5)
# ('else,', 2526, 0.5)
# ('because', 2526.5, 0.5)
# ('they', 2527, 0.5)
# ("didn't", 2527.5, 0.5)
# ('see', 2528, 0.5)
# ('him', 2528.5, 0.5)
# ('anywhere,', 2529, 0.5)
# ('but', 2529.5, 0.5)
# ('they', 2530, 0.5)
# ('hardly', 2530.5, 0.5)
# ('cared', 2531, 0.5)
# ('--', 2531.5, 0.5)
# ('all', 2532, 0.5)
# ('they', 2532.5, 0.5)
# ('wanted', 2533, 0.5)
# ('to', 2533.5, 0.5)
# ('do', 2534, 0.5)
# ('was', 2534.5, 0.5)
# ('put', 2535, 0.5)
# ('as', 2535.5, 0.5)
# ('much', 2536, 0.5)
# ('space', 2536.5, 0.5)
# ('as', 2537, 0.5)
# ('possible', 2537.5, 0.5)
# ('between', 2538, 0.5)
# ('them', 2538.5, 0.5)
# ('and', 2539, 0.5)
# ('that', 2539.5, 0.5)
# ('monster.', 2540, 0.5)
# ('They', 2540.5, 0.5)
# ("didn't", 2541, 0.5)
# ('stop', 2541.5, 0.5)
# ('running', 2542, 0.5)
# ('until', 2542.5, 0.5)
# ('they', 2543, 0.5)
# ('reached', 2543.5, 0.5)
# ('the', 2544, 0.5)
# ('portrait', 2544.5, 0.5)
# ('of', 2545, 0.5)
# ('the', 2545.5, 0.5)
# ('Fat', 2546, 0.5)
# ('Lady', 2546.5, 0.5)
# ('on', 2547, 0.5)
# ('the', 2547.5, 0.5)
# ('seventh', 2548, 0.5)
# ('floor.', 2548.5, 0.5)
# ('+', 2549, 0.5)
# ('"Where', 2549.5, 0.5)
# ('on', 2550, 0.5)
# ('earth', 2550.5, 0.5)
# ('have', 2551, 0.5)
# ('you', 2551.5, 0.5)
# ('all', 2552, 0.5)
# ('been?"', 2552.5, 0.5)
# ('she', 2553, 0.5)
# ('asked,', 2553.5, 0.5)
# ('looking', 2554, 0.5)
# ('at', 2554.5, 0.5)
# ('their', 2555, 0.5)
# ('bathrobes', 2555.5, 0.5)
# ('hanging', 2556, 0.5)
# ('off', 2556.5, 0.5)
# ('their', 2557, 0.5)
# ('shoulders', 2557.5, 0.5)
# ('and', 2558, 0.5)
# ('their', 2558.5, 0.5)
# ('flushed,', 2559, 0.5)
# ('sweaty', 2559.5, 0.5)
# ('faces.', 2560, 0.5)
# ('+', 2560.5, 0.5)
# ('"Never', 2561, 0.5)
# ('mind', 2561.5, 0.5)
# ('that', 2562, 0.5)
# ('--', 2562.5, 0.5)
# ('pig', 2563, 0.5)
# ('snout,', 2563.5, 0.5)
# ('pig', 2564, 0.5)
# ('snout,"', 2564.5, 0.5)
# ('panted', 2565, 0.5)
# ('Harry,', 2565.5, 0.5)
# ('and', 2566, 0.5)
# ('the', 2566.5, 0.5)
# ('portrait', 2567, 0.5)
# ('swung', 2567.5, 0.5)
# ('forward.', 2568, 0.5)
# ('They', 2568.5, 0.5)
# ('scrambled', 2569, 0.5)
# ('into', 2569.5, 0.5)
# ('the', 2570, 0.5)
# ('common', 2570.5, 0.5)
# ('room', 2571, 0.5)
# ('and', 2571.5, 0.5)
# ('collapsed,', 2572, 0.5)
# ('trembling,', 2572.5, 0.5)
# ('into', 2573, 0.5)
# ('armchairs.', 2573.5, 0.5)
# ('+', 2574, 0.5)
# ('It', 2574.5, 0.5)
# ('was', 2575, 0.5)
# ('a', 2575.5, 0.5)
# ('while', 2576, 0.5)
# ('before', 2576.5, 0.5)
# ('any', 2577, 0.5)
# ('of', 2577.5, 0.5)
# ('them', 2578, 0.5)
# ('said', 2578.5, 0.5)
# ('anything.', 2579, 0.5)
# ('Neville,', 2579.5, 0.5)
# ('indeed,', 2580, 0.5)
# ('looked', 2580.5, 0.5)
# ('as', 2581, 0.5)
# ('if', 2581.5, 0.5)
# ("he'd", 2582, 0.5)
# ('never', 2582.5, 0.5)
# ('speak', 2583, 0.5)
# ('again.', 2583.5, 0.5)
# ('+', 2584, 0.5)
# ('"What', 2584.5, 0.5)
# ('do', 2585, 0.5)
# ('they', 2585.5, 0.5)
# ('think', 2586, 0.5)
# ("they're", 2586.5, 0.5)
# ('doing,', 2587, 0.5)
# ('keeping', 2587.5, 0.5)
# ('a', 2588, 0.5)
# ('thing', 2588.5, 0.5)
# ('like', 2589, 0.5)
# ('that', 2589.5, 0.5)
# ('locked', 2590, 0.5)
# ('up', 2590.5, 0.5)
# ('in', 2591, 0.5)
# ('a', 2591.5, 0.5)
# ('school?"', 2592, 0.5)
# ('said', 2592.5, 0.5)
# ('Ron', 2593, 0.5)
# ('finally.', 2593.5, 0.5)
# ('"If', 2594, 0.5)
# ('any', 2594.5, 0.5)
# ('dog', 2595, 0.5)
# ('needs', 2595.5, 0.5)
# ('exercise,', 2596, 0.5)
# ('that', 2596.5, 0.5)
# ('one', 2597, 0.5)
# ('does."', 2597.5, 0.5)
# ('+', 2598, 0.5)
# ('Hermione', 2598.5, 0.5)
# ('had', 2599, 0.5)
# ('got', 2599.5, 0.5)
# ('both', 2600, 0.5)
# ('her', 2600.5, 0.5)
# ('breath', 2601, 0.5)
# ('and', 2601.5, 0.5)
# ('her', 2602, 0.5)
# ('bad', 2602.5, 0.5)
# ('temper', 2603, 0.5)
# ('back', 2603.5, 0.5)
# ('again.', 2604, 0.5)
# ('+', 2604.5, 0.5)
# ('"You', 2605, 0.5)
# ("don't", 2605.5, 0.5)
# ('use', 2606, 0.5)
# ('your', 2606.5, 0.5)
# ('eyes,', 2607, 0.5)
# ('any', 2607.5, 0.5)
# ('of', 2608, 0.5)
# ('you,', 2608.5, 0.5)
# ('do', 2609, 0.5)
# ('you?"', 2609.5, 0.5)
# ('she', 2610, 0.5)
# ('snapped.', 2610.5, 0.5)
# ('"Didn\'t', 2611, 0.5)
# ('you', 2611.5, 0.5)
# ('see', 2612, 0.5)
# ('what', 2612.5, 0.5)
# ('it', 2613, 0.5)
# ('was', 2613.5, 0.5)
# ('standing', 2614, 0.5)
# ('on?"', 2614.5, 0.5)
# ('+', 2615, 0.5)
# ('"The', 2615.5, 0.5)
# ('floor?"', 2616, 0.5)
# ('Harry', 2616.5, 0.5)
# ('suggested.', 2617, 0.5)
# ('"I', 2617.5, 0.5)
# ("wasn't", 2618, 0.5)
# ('looking', 2618.5, 0.5)
# ('at', 2619, 0.5)
# ('its', 2619.5, 0.5)
# ('feet,', 2620, 0.5)
# ('I', 2620.5, 0.5)
# ('was', 2621, 0.5)
# ('too', 2621.5, 0.5)
# ('busy', 2622, 0.5)
# ('with', 2622.5, 0.5)
# ('its', 2623, 0.5)
# ('heads."', 2623.5, 0.5)
# ('+', 2624, 0.5)
# ('"No,', 2624.5, 0.5)
# ('@not', 2625, 0.5)
# ('the', 2625.5, 0.5)
# ('floor.', 2626, 0.5)
# ('It', 2626.5, 0.5)
# ('was', 2627, 0.5)
# ('standing', 2627.5, 0.5)
# ('on', 2628, 0.5)
# ('a', 2628.5, 0.5)
# ('trapdoor.', 2629, 0.5)
# ("It's", 2629.5, 0.5)
# ('obviously', 2630, 0.5)
# ('guarding', 2630.5, 0.5)
# ('something."', 2631, 0.5)
# ('+', 2631.5, 0.5)
# ('She', 2632, 0.5)
# ('stood', 2632.5, 0.5)
# ('up,', 2633, 0.5)
# ('glaring', 2633.5, 0.5)
# ('at', 2634, 0.5)
# ('them.', 2634.5, 0.5)
# ('+', 2635, 0.5)
# ('"I', 2635.5, 0.5)
# ('hope', 2636, 0.5)
# ("you're", 2636.5, 0.5)
# ('pleased', 2637, 0.5)
# ('with', 2637.5, 0.5)
# ('yourselves.', 2638, 0.5)
# ('We', 2638.5, 0.5)
# ('could', 2639, 0.5)
# ('all', 2639.5, 0.5)
# ('have', 2640, 0.5)
# ('been', 2640.5, 0.5)
# ('killed', 2641, 0.5)
# ('--', 2641.5, 0.5)
# ('or', 2642, 0.5)
# ('worse,', 2642.5, 0.5)
# ('expelled.', 2643, 0.5)
# ('Now,', 2643.5, 0.5)
# ('if', 2644, 0.5)
# ('you', 2644.5, 0.5)
# ("don't", 2645, 0.5)
# ('mind,', 2645.5, 0.5)
# ("I'm", 2646, 0.5)
# ('going', 2646.5, 0.5)
# ('to', 2647, 0.5)
# ('bed."', 2647.5, 0.5)
# ('+', 2648, 0.5)
# ('Ron', 2648.5, 0.5)
# ('stared', 2649, 0.5)
# ('after', 2649.5, 0.5)
# ('her,', 2650, 0.5)
# ('his', 2650.5, 0.5)
# ('mouth', 2651, 0.5)
# ('open.', 2651.5, 0.5)
# ('"No,', 2652, 0.5)
# ('we', 2652.5, 0.5)
# ("don't", 2653, 0.5)
# ('mind,"', 2653.5, 0.5)
# ('he', 2654, 0.5)
# ('said.', 2654.5, 0.5)
# ('"You\'d', 2655, 0.5)
# ('think', 2655.5, 0.5)
# ('we', 2656, 0.5)
# ('dragged', 2656.5, 0.5)
# ('her', 2657, 0.5)
# ('along,', 2657.5, 0.5)
# ("wouldn't", 2658, 0.5)
# ('you?"', 2658.5, 0.5)
# ('+', 2659, 0.5)
# ('But', 2659.5, 0.5)
# ('Hermione', 2660, 0.5)
# ('had', 2660.5, 0.5)
# ('given', 2661, 0.5)
# ('Harry', 2661.5, 0.5)
# ('something', 2662, 0.5)
# ('else', 2662.5, 0.5)
# ('to', 2663, 0.5)
# ('think', 2663.5, 0.5)
# ('about', 2664, 0.5)
# ('as', 2664.5, 0.5)
# ('he', 2665, 0.5)
# ('climbed', 2665.5, 0.5)
# ('back', 2666, 0.5)
# ('into', 2666.5, 0.5)
# ('bed.', 2667, 0.5)
# ('The', 2667.5, 0.5)
# ('dog', 2668, 0.5)
# ('was', 2668.5, 0.5)
# ('guarding', 2669, 0.5)
# ('something.', 2669.5, 0.5)
# ('.', 2670, 0.5)
# ('.', 2670.5, 0.5)
# ('.', 2671, 0.5)
# ('What', 2671.5, 0.5)
# ('had', 2672, 0.5)
# ('Hagrid', 2672.5, 0.5)
# ('said?', 2673, 0.5)
# ('Gringotts', 2673.5, 0.5)
# ('was', 2674, 0.5)
# ('the', 2674.5, 0.5)
# ('safest', 2675, 0.5)
# ('place', 2675.5, 0.5)
# ('in', 2676, 0.5)
# ('the', 2676.5, 0.5)
# ('world', 2677, 0.5)
# ('for', 2677.5, 0.5)
# ('something', 2678, 0.5)
# ('you', 2678.5, 0.5)
# ('wanted', 2679, 0.5)
# ('to', 2679.5, 0.5)
# ('hide', 2680, 0.5)
# ('--', 2680.5, 0.5)
# ('except', 2681, 0.5)
# ('perhaps', 2681.5, 0.5)
# ('Hogwarts.', 2682, 0.5)
# ('+', 2682.5, 0.5)
# ('It', 2683, 0.5)
# ('looked', 2683.5, 0.5)
# ('as', 2684, 0.5)
# ('though', 2684.5, 0.5)
# ('Harry', 2685, 0.5)
# ('had', 2685.5, 0.5)
# ('found', 2686, 0.5)
# ('out', 2686.5, 0.5)
# ('where', 2687, 0.5)
# ('the', 2687.5, 0.5)
# ('grubby', 2688, 0.5)
# ('little', 2688.5, 0.5)
# ('package', 2689, 0.5)
# ('from', 2689.5, 0.5)
# ('vault', 2690, 0.5)
# ('seven', 2690.5, 0.5)
# ('hundred', 2691, 0.5)
# ('and', 2691.5, 0.5)
# ('thirteen', 2692, 0.5)
# ('was.', 2692.5, 0.5)
# ('+', 2693, 9)

# %%
sample_per_second

ds_cleaner_transform = []

#load in the start
first_time = s3['words'][0][1]

start_missing_samples = int(first_time / sample_per_second)

for i in range(0, start_missing_samples):
    ds_cleaner_transform.append("-")
    
ds_cleaner_transform
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
for value in s3['words']:
    
    #it is a normal word...
    if value[2] == 0.5:
        ds_cleaner_transform.append("+")
        
    #if the thing is greater... it's a pause    
    elif value[2] > 0.5:
        #if the thing is greater... it's a pause
        for num in range(0, value[2]):
            print("adding")
            #s_cleaner_transform.append("-")
        print("true")
        ds_cleaner_transform.append("-")
    else:
        print("error")
        print(value)
# Out:
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# true
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# true
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# true
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# adding
# true

# %%
ds_cleaner_transform
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  '+',
#  ...]

# %%
len(ds_cleaner_transform)
# Out:
# 10456

# %%
for value in ds_cleaner_transform:
    total = total + 1
    if value == "-":
        print("true")
# Out:
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true
# true

# %%
words = s3['words']

# %%
#there should be 4 sameples in each fmri sample - each sample is 2 seconds, 
#words should appear every 0.5 seconds...therefore we should look in groups of 4
for i in range(0, len(words), 4):
    sample_words = []
    
    found_break = False
    
    for j in range(0, 4):
        sample_words.append(words[i + j])
    
    for word in sample_words:
        if word[2] > 0.5:
            print("found greater")
            found_break = True
            
    if found_break:
        for word in sample_words:
            print(word)
        
        print("")
# Out:
# found greater
# ('it', 670, 0.5)
# ('up.', 670.5, 0.5)
# ('+', 671, 9)
# ('"Give', 700, 0.5)
#
# found greater
# ('you."', 1374.5, 0.5)
# ('+', 1375, 9)
# ('Fred', 1404, 0.5)
# ('and', 1404.5, 0.5)
#
# found greater
# ('+', 1933, 9)
# ('Ron', 1962, 0.5)
# ('looked', 1962.5, 0.5)
# ('at', 1963, 0.5)
#
# found greater
# ('and', 2691.5, 0.5)
# ('thirteen', 2692, 0.5)
# ('was.', 2692.5, 0.5)
# ('+', 2693, 9)
